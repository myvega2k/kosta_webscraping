# %% [markdown]
# ### Melon 100 챠트 스크래핑
# * 100곡 노래의 제목,ID를 추출
# * Song ID를 상세 페이지를 100번 요청을 해서 상세정보를 추출
# * 100곡의 노래상세정보를 Json file에 저장한다
# * Json file에 정보를 읽어서 Pandas의 DataFrame에 저장해서 표 데이터를 만들기
# * 표 데이터를 Maria DB에 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.melon.com/chart/index.htm'
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

# 요청을 보내기
res = requests.get(url, headers=req_header)
print(type(res))
# 응답코드 200(ok) 가 정상이면
if res.ok:
    #response 객체에 포함된 text를 추출
    html = res.text
    #BeautifulSoup 객체의 역할 - html 문서 파싱
    #텍스트를 추출(parsing)하기 위해서 응답 text와 parser 이름을 전달한다.
    soup = BeautifulSoup(html, 'html.parser')
    
    #<div id='tb_list'> div 태그 선택
    print(len(soup.select('div#tb_list'))) #1
    #<div id='tb_list'> 하위에 있는 tr 태그 선택
    print(len(soup.select('div#tb_list tr'))) #101
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'>
    print(len(soup.select('div#tb_list tr div.wrap_song_info'))) #200
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 하위에 a 태그 
    print(len(soup.select('div#tb_list tr div.wrap_song_info a'))) #423
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 하위에 a 태그 
    #a 태그의 href 속성값에 playSong이라는 문자열 포함된 a 태그를 선택 #100
    print(len(soup.select('div#tb_list tr div.wrap_song_info a[href*="playSong"]')))
    
    atag_list = soup.select('div#tb_list tr div.wrap_song_info a[href*="playSong"]')
    song_list = []
    
    for idx,atag in enumerate(atag_list,1):
        song_dict = {}
        title = atag.text   #<a>노래제목</a>  a tag의 text를 추출
        href = atag['href'] #<a href="playSong">   href속성의 값을 추출
        matched = re.search(r'(\d+)\);', href)  # 정규표현식 패턴으로 숫자를 검색
        song_id = matched.group(1) # 정규표현식 결과값을 가져오기
        #song 상세페이지 url를 조립
        detail_link = f'https://www.melon.com/song/detail.htm?songId={song_id}'
        #song 의 제목과 상세페이지url를 dict에 저장
        song_dict['title'] = title
        song_dict['song_id'] = song_id
        song_dict['link'] = detail_link
        #각각의 song 정보를 저장한 dict를 list에 저장
        song_list.append(song_dict)
else:
    print('Error 코드 ', res.status_code)

print(len(song_list))
song_list[0:3]
# Out:
# <class 'requests.models.Response'>
# 1
# 101
# 200
# 427
# 100
# 100
# [{'title': 'STAY',
#   'song_id': '33658563',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33658563'},
#  {'title': '신호등',
#   'song_id': '33480898',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33480898'},
#  {'title': 'My Universe',
#   'song_id': '33998510',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33998510'}]

# %% [markdown]
# #### Song ID를 상세 페이지를 100번 요청을 해서 상세정보를 추출

# %%
song_list[71:]
# Out:
# [{'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   'song_id': '32003395',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32003395'},
#  {'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)',
#   'song_id': '31853557',
#   'link': 'https://www.melon.com/song/detail.htm?songId=31853557'},
#  {'title': '에잇(Prod.&Feat. SUGA of BTS)',
#   'song_id': '32578498',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32578498'},
#  {'title': '상상더하기',
#   'song_id': '8130796',
#   'link': 'https://www.melon.com/song/detail.htm?songId=8130796'},
#  {'title': '그날에 나는 맘이 편했을까',
#   'song_id': '33107649',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33107649'},
#  {'title': '어푸 (Ah puh)',
#   'song_id': '33372788',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33372788'},
#  {'title': '고백',
#   'song_id': '34002022',
#   'link': 'https://www.melon.com/song/detail.htm?songId=34002022'},
#  {'title': 'LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)',
#   'song_id': '33331004',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33331004'},
#  {'title': '2002',
#   'song_id': '31029291',
#   'link': 'https://www.melon.com/song/detail.htm?songId=31029291'},
#  {'title': '여전히 아름다운지',
#   'song_id': '33800786',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33800786'},
#  {'title': '산책',
#   'song_id': '33939317',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33939317'},
#  {'title': '이젠 잊기로 해요 (Drama Ver.)',
#   'song_id': '33742378',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33742378'},
#  {'title': '나를 아는 사람',
#   'song_id': '33625989',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33625989'},
#  {'title': '고백',
#   'song_id': '33772329',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33772329'},
#  {'title': 'METEOR',
#   'song_id': '32224272',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32224272'},
#  {'title': '미워요',
#   'song_id': '8302665',
#   'link': 'https://www.melon.com/song/detail.htm?songId=8302665'},
#  {'title': '사랑의 아픔 딛고',
#   'song_id': '33728859',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33728859'},
#  {'title': '너 하나야 (낮에 뜨는 달 X 길구봉구)',
#   'song_id': '33976402',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33976402'},
#  {'title': 'Dolphin',
#   'song_id': '32559782',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32559782'},
#  {'title': '12:45 (Stripped)',
#   'song_id': '31509376',
#   'link': 'https://www.melon.com/song/detail.htm?songId=31509376'},
#  {'title': '계단말고 엘리베이터',
#   'song_id': '31254010',
#   'link': 'https://www.melon.com/song/detail.htm?songId=31254010'},
#  {'title': '전화 한 번 못하니',
#   'song_id': '33999944',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33999944'},
#  {'title': 'Road Trip',
#   'song_id': '33901885',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33901885'},
#  {'title': '목로주점',
#   'song_id': '33408084',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33408084'},
#  {'title': 'Butterfly',
#   'song_id': '33976671',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33976671'},
#  {'title': '너의 번호를 누르고 (Prod. 영화처럼)',
#   'song_id': '32224166',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32224166'},
#  {'title': '사실 나는 (Feat.전건호)',
#   'song_id': '32525311',
#   'link': 'https://www.melon.com/song/detail.htm?songId=32525311'},
#  {'title': '내일의 나에게 (The Rainy Night)',
#   'song_id': '33901881',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33901881'},
#  {'title': '나랑 같이 걸을래 (바른연애 길잡이 X 적재)',
#   'song_id': '33011180',
#   'link': 'https://www.melon.com/song/detail.htm?songId=33011180'}]

# %%
import requests
from bs4 import BeautifulSoup
import re

req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

song_detail_list = []
for idx,song in enumerate(song_list,1):
    song_detail_dict = {}
    song_url = song['link']
    res = requests.get(song_url, headers=req_header)
    print(idx, song['title'])
    if res.ok:
        html = res.text
        soup = BeautifulSoup(html,'html.parser')
        #노래제목
        song_detail_dict['곡명'] = song['title']
        #가수
        song_detail_dict['가수'] = soup.select('a[href*="goArtistDetail"] span')[0].text
        #앨범
        song_detail_dict['앨범'] = soup.select('div.meta dd')[0].text
        #발매일
        song_detail_dict['발매일'] = soup.select('div.meta dd')[1].text
        #장르
        song_detail_dict['장르'] = soup.select('div.meta dd')[2].text   
        
        #좋아요건수
        song_id = song['song_id']
        like_url = f'https://www.melon.com/commonlike/getSongLike.json?contsIds={song_id}'
        like_res = requests.get(like_url,headers=req_header)
        like_cnt = like_res.json()['contsLike'][0]['SUMMCNT']
        song_detail_dict['좋아요'] = like_cnt
        
        #가사
        if soup.select('div#d_video_summary'):
            lyric = soup.select('div#d_video_summary')[0].text
        else:
            lyric = ''
        regexp = re.compile(r'[\n\r\t]')        
        song_detail_dict['가사'] = regexp.sub('',lyric.strip())
        #각각의 Song정보를 담고 있는 dict를 list에 저장
        song_detail_list.append(song_detail_dict)

print(len(song_detail_list))
print(song_detail_list[0:2])
# Out:
# 1 STAY
# 2 신호등
# 3 My Universe
# 4 OHAYO MY NIGHT
# 5 Permission to Dance
# 6 Next Level
# 7 바라만 본다
# 8 Butter
# 9 낙하 (with 아이유)
# 10 Weekend
# 11 좋아좋아
# 12 Peaches (Feat. Daniel Caesar & Giveon)
# 13 다정히 내 이름을 부르면
# 14 Queendom
# 15 Bad Habits
# 16 Dynamite
# 17 헤픈 우연
# 18 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 19 DUMB DUMB
# 20 비와 당신
# 21 가을 타나 봐
# 22 고백
# 23 이제 나만 믿어요
# 24 비가 오는 날엔 (2021)
# 25 라일락
# 26 Dun Dun Dance
# 27 롤린 (Rollin')
# 28 Celebrity
# 29 ASAP
# 30 색안경 (STEREOTYPE)
# 31 Savage Love (Laxed - Siren Beat) (BTS Remix)
# 32 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 33 가을 우체국 앞에서
# 34 별빛 같은 나의 사랑아
# 35 하루만 더
# 36 Sticker
# 37 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 38 그대라는 사치
# 39 밝게 빛나는 별이 되어 비춰줄게
# 40 내 손을 잡아
# 41 너를 생각해
# 42 HERO
# 43 다시 사랑한다면 (김필 Ver.)
# 44 찰나가 영원이 될 때 (The Eternal Moment)
# 45 LOCO
# 46 봄날
# 47 치맛바람 (Chi Mat Ba Ram)
# 48 안녕 (Hello)
# 49 Off My Face
# 50 Alcohol-Free
# 51 밤하늘의 별을(2020)
# 52 Life Goes On
# 53 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 54 Lovesick Girls
# 55 추억은 만남보다 이별에 남아
# 56 끝사랑
# 57 운전만해 (We Ride)
# 58 Bk Love
# 59 잊었니
# 60 빨간 립스틱 (Feat. 윤미래)
# 61 멜로디
# 62 Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afrojack)
# 63 아로하
# 64 취기를 빌려 (취향저격 그녀 X 산들)
# 65 잠이 오질 않네요
# 66 Timeless
# 67 Blueming
# 68 Lemonade
# 69 모든 날, 모든 순간 (Every day, Every Moment)
# 70 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 71 오래된 노래
# 72 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 73 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 74 에잇(Prod.&Feat. SUGA of BTS)
# 75 상상더하기
# 76 그날에 나는 맘이 편했을까
# 77 어푸 (Ah puh)
# 78 고백
# 79 LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 80 2002
# 81 여전히 아름다운지
# 82 산책
# 83 이젠 잊기로 해요 (Drama Ver.)
# 84 나를 아는 사람
# 85 고백
# 86 METEOR
# 87 미워요
# 88 사랑의 아픔 딛고
# 89 너 하나야 (낮에 뜨는 달 X 길구봉구)
# 90 Dolphin
# 91 12:45 (Stripped)
# 92 계단말고 엘리베이터
# 93 전화 한 번 못하니
# 94 Road Trip
# 95 목로주점
# 96 Butterfly
# 97 너의 번호를 누르고 (Prod. 영화처럼)
# 98 사실 나는 (Feat.전건호)
# 99 내일의 나에게 (The Rainy Night)
# 100 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 100
# [{'곡명': 'STAY', '가수': 'The Kid LAROI', '앨범': 'Stay', '발매일': '2021.07.09', '장르': 'POP', '좋아요': 155719, '가사': "I do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay hey OhI get drunk wake upI'm wasted stillI realize the timethat I wasted hereI feel like you can'tfeel the way I feelOh I'll be fucked upif you can't be right hereOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahOh I'll be fucked upif you can't be right hereI do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyI do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyWhen I'm away from youI miss your touch OohYou're the reasonI believe in love OohIt's been difficultfor me to trust OohAnd I'm afraidthat I'ma fuck it up OohAin't no waythat I can leave you stranded'Cause you ain't ever left meempty-handedAnd you know that I knowthat I can't live without youSo baby stayOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahI'll be fucked upif you can't be right hereI do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyI do the same thingI told you that I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyWoah-ohI need you to stayneed you to stay hey"}, {'곡명': '신호등', '가수': '이무진', '앨범': '신호등', '발매일': '2021.05.14', '장르': '록/메탈', '좋아요': 216878, '가사': '이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던친구가 생각나네이미 난 발걸음을 떼었지만가려한 날 재촉하네 걷기도 힘든데새파랗게 겁에 질려 도망간친구가 뇌에 맴도네건반처럼 생긴 도로 위수많은 동그라미들 모두가멈췄다 굴렀다 말은 잘 들어그건 나도 문제가 아냐붉은색 푸른색 그 사이3초 그 짧은 시간노란색 빛을 내는저기 저 신호등이내 머릿속을 텅 비워버려내가 빠른지도느린지도 모르겠어그저 눈앞이 샛노랄 뿐이야솔직히 말하자면 차라리운전대를 못 잡던 어릴 때가더 좋았었던 것 같아그땐 함께 온 세상을거닐 친구가 있었으니건반처럼 생긴 도로 위수많은 조명들이 날 빠르게번갈아 가며 비추고 있지만난 아직 초짜란 말이야붉은색 푸른색 그 사이3초 그 짧은 시간노란색 빛을 내는 저기 저 신호등이내 머릿속을 텅 비워버려내가 빠른지도느린지도 모르겠어그저 눈앞이 샛노랄 뿐이야꼬질꼬질한 사람이나부자 곁엔 아무도 없는삼색 조명과 이색 칠 위에서 있어 괴롭히지 마붉은색 푸른색 그 사이3초 그 짧은 시간노란색 빛을 내는 저기 저 신호등이내 머릿속을 텅 비워버려내가 빠른지도느린지도 모르겠어그저 눈앞이 샛노랄 뿐이야'}]

# %% [markdown]
# #### Song 정보를 담고 있는 List를 JSON file로 저장

# %%
import json

with open('data/songs.json','w', encoding='utf8') as file:
    json.dump(song_detail_list, file)

# %% [markdown]
# #### Json File 읽기

# %%
import json

with open('data/songs.json','r',encoding='utf8') as file:
    contents = file.read()
    song_json = json.loads(contents)
    
print(len(song_json))
print(type(song_json))
# Out:
# 100
# <class 'list'>

# %% [markdown]
# #### Json file을 읽어서 Pandas의 DataFrame 객체에 저장

# %%
import pandas as pd

song_df2 = pd.read_json('data/songs.json')
song_df2.head()
# Out:
#               곡명             가수                           앨범         발매일  \
# 0         Savage          aespa  Savage - The 1st Mini Album  2021.10.05
# 1           STAY  The Kid LAROI                         Stay  2021.07.09
# 2    My Universe       Coldplay                  My Universe  2021.09.24
# 3            신호등            이무진                          신호등  2021.05.14
# 4  낙하 (with 아이유)      AKMU (악뮤)                 NEXT EPISODE  2021.07.26
#
#      장르     좋아요                                                 가사
# 0    댄스   51107  Oh my gosh!Don't you know I’m a Savage?I’m a K...
# 1   POP  165140  I do the same thing I told youthat I never wou...
# 2   POP  104769  You, you are my universe andI just want to put...
# 3  록/메탈  222188  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 4  록/메탈  133812  말했잖아 언젠가이런 날이 온다면난 널 혼자 내버려두지 않을 거라고 죄다 낭떠러지야,...

# %%
song_df2.tail()
# Out:
#                            곡명       가수                         앨범         발매일  \
# 95                  Butterfly      전미도  슬기로운 의사생활 시즌2 OST Part 12  2021.09.17
# 96    너의 번호를 누르고 (Prod. 영화처럼)      #안녕                 너의 번호를 누르고  2019.11.30
# 97           사실 나는 (Feat.전건호)     경서예지                      사실 나는  2020.04.12
# 98  내일의 나에게 (The Rainy Night)  NCT 127    Sticker - The 3rd Album  2021.09.17
# 99  나랑 같이 걸을래 (바른연애 길잡이 X 적재)       적재  나랑 같이 걸을래 (바른연애 길잡이 X 적재)  2020.10.23
#
#              장르     좋아요                                                 가사
# 95  록/메탈, 국내드라마   18154  어리석은 세상은 너를 몰라누에 속에 감춰진 너를 못 봐나는 알아 내겐 보여그토록 찬...
# 96    발라드, 인디음악   88904  우연히 너를 만나서너의 옆자리에 앉아그렇게 우린 친해졌어짧은 시간에 그렇게가까워질 ...
# 97          발라드   83692  그땐 우리 둘 다 철없이어리기만 했나 봐태어나 처음 설레는너를 만나서 세상에 부러울...
# 98          발라드   35627  Yeah yeah listen너와 듣던 이 음악을되감아봐 이 밤에또 흩어지지 못한 ...
# 99    발라드, 인디음악  114341  가을밤이 찾아와그대를 비추고또 나를 감싸네눈을 감을 때마다향기로운 네 맘이내게 전해...

# %%
import pandas as pd

#DataFrame 객체 생성
song_df = pd.DataFrame(columns=['곡명','가수','앨범','발매일','장르','좋아요','가사'])
#song_df

for song in song_detail_list:
    series_obj = pd.Series(song)
    song_df = song_df.append(series_obj, ignore_index=True)

song_df.head(3)
# Out:
#             곡명             가수           앨범         발매일    장르     좋아요  \
# 0         STAY  The Kid LAROI         Stay  2021.07.09   POP  155719
# 1          신호등            이무진          신호등  2021.05.14  록/메탈  216878
# 2  My Universe       Coldplay  My Universe  2021.09.24   POP   82762
#
#                                                   가사
# 0  I do the same thing I told youthat I never wou...
# 1  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 2  You, you are my universe andI just want to put...

# %%
song_df.tail(3)
# Out:
#                            곡명       가수                         앨범         발매일  \
# 97           사실 나는 (Feat.전건호)     경서예지                      사실 나는  2020.04.12
# 98  내일의 나에게 (The Rainy Night)  NCT 127    Sticker - The 3rd Album  2021.09.17
# 99  나랑 같이 걸을래 (바른연애 길잡이 X 적재)       적재  나랑 같이 걸을래 (바른연애 길잡이 X 적재)  2020.10.23
#
#            장르     좋아요                                                 가사
# 97        발라드   83692  그땐 우리 둘 다 철없이어리기만 했나 봐태어나 처음 설레는너를 만나서 세상에 부러울...
# 98        발라드   35627  Yeah yeah listen너와 듣던 이 음악을되감아봐 이 밤에또 흩어지지 못한 ...
# 99  발라드, 인디음악  114341  가을밤이 찾아와그대를 비추고또 나를 감싸네눈을 감을 때마다향기로운 네 맘이내게 전해...

# %%
song_df.sample(5)
# Out:
#                 곡명            가수                    앨범         발매일  \
# 70          오래된 노래        스탠딩 에그                오래된 노래  2012.09.04
# 62             아로하           조정석  슬기로운 의사생활 OST Part 3  2020.03.27
# 40          너를 생각해  주시크 (Joosiq)                너를 생각해  2021.09.22
# 18       DUMB DUMB           전소미             DUMB DUMB  2021.08.02
# 53  Lovesick Girls     BLACKPINK             THE ALBUM  2020.10.02
#
#                 장르     좋아요                                                 가사
# 70    인디음악, 포크/블루스  235614  오래 전에 함께 듣던 노래가발걸음을 다시 멈춰서게 해이 거리에서너를 느낄 수 있어널...
# 62      발라드, 국내드라마  228435  어두운 불빛아래 촛불 하나와인 잔에 담긴 약속하나항상 너의 곁에서 널 지켜줄거야날 ...
# 40  R&B/Soul, 인디음악   13795  너를 들려주고 싶었어이 노랠 만들 때아마 니가 정말 많이 좋아할꺼야이젠 내겐 니가 ...
# 18              댄스   71594  거울 앞에서 또 연습해두 눈을 크게 떠이런 표정을 넌 좋아해어떻게 하면 더 연약해 ...
# 53              댄스  203021  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...

# %%
print('shape ', song_df.shape)
print('colums ', song_df.columns)
print('index ', song_df.index)
print('values ', song_df.values[0:1]) #2차원 배열
# Out:
# shape  (100, 7)
# colums  Index(['곡명', '가수', '앨범', '발매일', '장르', '좋아요', '가사'], dtype='object')
# index  RangeIndex(start=0, stop=100, step=1)
# values  [['STAY' 'The Kid LAROI' 'Stay' '2021.07.09' 'POP' 155719
#   "I do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay hey OhI get drunk wake upI'm wasted stillI realize the timethat I wasted hereI feel like you can'tfeel the way I feelOh I'll be fucked upif you can't be right hereOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahOh I'll be fucked upif you can't be right hereI do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyI do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyWhen I'm away from youI miss your touch OohYou're the reasonI believe in love OohIt's been difficultfor me to trust OohAnd I'm afraidthat I'ma fuck it up OohAin't no waythat I can leave you stranded'Cause you ain't ever left meempty-handedAnd you know that I knowthat I can't live without youSo baby stayOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahOh ooh-woahOh ooh-woah ooh-woahI'll be fucked upif you can't be right hereI do the same thing I told youthat I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyI do the same thingI told you that I never wouldI told you I'd changeeven when I knew I never couldI know that I can't findnobody elseas good as youI need you to stayneed you to stay heyWoah-ohI need you to stayneed you to stay hey"]]

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   곡명      100 non-null    object
#  1   가수      100 non-null    object
#  2   앨범      100 non-null    object
#  3   발매일     100 non-null    object
#  4   장르      100 non-null    object
#  5   좋아요     100 non-null    object
#  6   가사      100 non-null    object
# dtypes: object(7)
# memory usage: 5.6+ KB

# %%
#가수 컬럼의 값을 선택
song_df['가수']
# Out:
# 0     The Kid LAROI
# 1               이무진
# 2          Coldplay
# 3       디핵 (D-Hack)
# 4             방탄소년단
#           ...
# 95              전미도
# 96              #안녕
# 97             경서예지
# 98          NCT 127
# 99               적재
# Name: 가수, Length: 100, dtype: object

# %%
#가수별로 row counting
song_df['가수'].value_counts().head(10)
# Out:
# 임영웅                  12
# 아이유                   6
# 방탄소년단                 6
# NCT 127               4
# 브레이브걸스                3
# 이무진                   3
# 헤이즈 (Heize)           2
# AKMU (악뮤)             2
# 오마이걸 (OH MY GIRL)     2
# STAYC(스테이씨)           2
# Name: 가수, dtype: int64

# %%
#장르별 row counting
song_df['장르'].value_counts()
# Out:
# 댄스                23
# 발라드               19
# 랩/힙합              10
# 성인가요              10
# POP                8
# 발라드, 국내드라마         7
# 록/메탈               6
# R&B/Soul           4
# 록/메탈, 국내드라마        4
# 발라드, 인디음악          3
# R&B/Soul, 인디음악     3
# 포크/블루스             1
# 인디음악, 포크/블루스       1
# 일렉트로니카             1
# Name: 장르, dtype: int64

# %%
#unique 한 장르명 가져오기
song_df['장르'].unique()
# Out:
# array(['POP', '록/메탈', '랩/힙합', '댄스', '발라드', '발라드, 국내드라마', 'R&B/Soul',
#        '록/메탈, 국내드라마', '포크/블루스', '발라드, 인디음악', '성인가요', 'R&B/Soul, 인디음악',
#        '일렉트로니카', '인디음악, 포크/블루스'], dtype=object)

# %%
#가사 empty string check
song_df.loc[song_df['가사'] == '']
# Out:
#                                                    곡명            가수      앨범  \
# 61  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...  David Guetta  Listen
#
#            발매일      장르    좋아요 가사
# 61  2014.11.25  일렉트로니카  40549

# %%
#방탄소년단 의 노래를 모두 선택
song_df['가수'] == '방탄소년단'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: 가수, Length: 100, dtype: bool

# %% [markdown]
# ### 특정행이나 열을 선택
# * loc[]  과 iloc[] 사용
# * 1) Slicing 을 사용해서 구간을 선택 행과열을 선택  :
# * 2) 특정행과 특정열을 선택 [ ]
# * 3) 조건식을 만족하는 행을 선택

# %%
#loc[]  - location의 약자
#특정행이나 특정열을 선택할 때 사용한다. 
#loc[행을 선택 기준 ,  열을 선택 기준 ]

#인덱스가 0 부터 5까지의 행과 모든열을 선택
song_df.loc[0:5,:]
# Out:
#                     곡명             가수                            앨범  \
# 0                 STAY  The Kid LAROI                          Stay
# 1                  신호등            이무진                           신호등
# 2          My Universe       Coldplay                   My Universe
# 3       OHAYO MY NIGHT    디핵 (D-Hack)                OHAYO MY NIGHT
# 4  Permission to Dance          방탄소년단  Butter / Permission to Dance
# 5           Next Level          aespa                    Next Level
#
#           발매일    장르     좋아요                                                 가사
# 0  2021.07.09   POP  155719  I do the same thing I told youthat I never wou...
# 1  2021.05.14  록/메탈  216878  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 2  2021.09.24   POP   82762  You, you are my universe andI just want to put...
# 3  2020.06.20  랩/힙합  135318  너를 사랑하고 있어너를 사랑하고 있어자기야 날 사랑해주면 안 될까말처럼 쉽지는 않은...
# 4  2021.07.09    댄스  177415  It’s the thought of being youngWhen your heart...
# 5  2021.05.17    댄스  207236  I’m on the Next Level Yeah절대적 룰을 지켜내 손을 놓지 말아결...

# %%
#Slicing으로 인덱스가 0부터 8까지 , 1줄 씩 skip
song_df.loc[0:8:2,:]
# Out:
#                     곡명             가수                            앨범  \
# 0                 STAY  The Kid LAROI                          Stay
# 2          My Universe       Coldplay                   My Universe
# 4  Permission to Dance          방탄소년단  Butter / Permission to Dance
# 6               바라만 본다  MSG워너비(M.O.M)                     MSG워너비 1집
# 8        낙하 (with 아이유)      AKMU (악뮤)                  NEXT EPISODE
#
#           발매일    장르     좋아요                                                 가사
# 0  2021.07.09   POP  155719  I do the same thing I told youthat I never wou...
# 2  2021.09.24   POP   82762  You, you are my universe andI just want to put...
# 4  2021.07.09    댄스  177415  It’s the thought of being youngWhen your heart...
# 6  2021.06.26   발라드  157331  내가 너라면 다 알아볼 텐데널 위할 사람 찾아낼 텐데지난 오랜 시간 너의 그 곁을지...
# 8  2021.07.26  록/메탈  126391  말했잖아 언젠가이런 날이 온다면난 널 혼자 내버려두지 않을 거라고 죄다 낭떠러지야,...

# %%
#여러개의 특정 행과 모든열을 선택
song_df.loc[[0,3,7,8]]
#song_df.loc[[0,3,7,8],:]
# Out:
#                곡명             가수              앨범         발매일    장르     좋아요  \
# 0            STAY  The Kid LAROI            Stay  2021.07.09   POP  155719
# 3  OHAYO MY NIGHT    디핵 (D-Hack)  OHAYO MY NIGHT  2020.06.20  랩/힙합  135318
# 7          Butter          방탄소년단          Butter  2021.05.21    댄스  244672
# 8   낙하 (with 아이유)      AKMU (악뮤)    NEXT EPISODE  2021.07.26  록/메탈  126391
#
#                                                   가사
# 0  I do the same thing I told youthat I never wou...
# 3  너를 사랑하고 있어너를 사랑하고 있어자기야 날 사랑해주면 안 될까말처럼 쉽지는 않은...
# 7  Smooth like butterLike a criminal undercoverGo...
# 8  말했잖아 언젠가이런 날이 온다면난 널 혼자 내버려두지 않을 거라고 죄다 낭떠러지야,...

# %%
#조건식을 만족하는 행과 모든열을 선택
condition = song_df['가수'] == '방탄소년단'
song_df.loc[condition, :]
# Out:
#                                            곡명     가수  \
# 4                         Permission to Dance  방탄소년단
# 7                                      Butter  방탄소년단
# 15                                   Dynamite  방탄소년단
# 36  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  방탄소년단
# 45                                         봄날  방탄소년단
# 51                               Life Goes On  방탄소년단
#
#                               앨범         발매일    장르     좋아요  \
# 4   Butter / Permission to Dance  2021.07.09    댄스  177415
# 7                         Butter  2021.05.21    댄스  244672
# 15    Dynamite (DayTime Version)  2020.08.24    댄스  424022
# 36     MAP OF THE SOUL : PERSONA  2019.04.12    댄스  429187
# 45          YOU NEVER WALK ALONE  2017.02.13  랩/힙합  549192
# 51                            BE  2020.11.20  랩/힙합  227121
#
#                                                    가사
# 4   It’s the thought of being youngWhen your heart...
# 7   Smooth like butterLike a criminal undercoverGo...
# 15  Cos ah ahI’m in the stars tonightSo watch me b...
# 36  모든 게 궁금해How’s your dayOh tell me뭐가 널 행복하게 하는지O...
# 45  보고 싶다이렇게 말하니까 더 보고 싶다너희 사진을 보고 있어도보고 싶다너무 야속한 ...
# 51  어느 날 세상이 멈췄어아무런 예고도 하나 없이봄은 기다림을 몰라서눈치 없이 와버렸어...

# %%
#모든행과 특정열을 1개 선택
#song_df['가수']
song_df.loc[:,'가수'].head()
# Out:
# 0    The Kid LAROI
# 1              이무진
# 2         Coldplay
# 3      디핵 (D-Hack)
# 4            방탄소년단
# Name: 가수, dtype: object

# %%
#모든행과 특정열을 여러개 선택
song_df.loc[:,['가수','곡명','장르']].head()
# Out:
#               가수                   곡명    장르
# 0  The Kid LAROI                 STAY   POP
# 1            이무진                  신호등  록/메탈
# 2       Coldplay          My Universe   POP
# 3    디핵 (D-Hack)       OHAYO MY NIGHT  랩/힙합
# 4          방탄소년단  Permission to Dance    댄스

# %%
#장르가 댄스인 가수,곡명,장르,발매일을 선택하세요
song_df.loc[song_df['장르'] == '댄스',['가수','곡명','장르','발매일']]\
.reset_index(drop=True)
# Out:
#                    가수                                         곡명  장르  \
# 0               방탄소년단                        Permission to Dance  댄스
# 1               aespa                                 Next Level  댄스
# 2               방탄소년단                                     Butter  댄스
# 3        태연 (TAEYEON)                                    Weekend  댄스
# 4   Red Velvet (레드벨벳)                                   Queendom  댄스
# 5               방탄소년단                                   Dynamite  댄스
# 6                 전소미                                  DUMB DUMB  댄스
# 7                 아이유                                        라일락  댄스
# 8   오마이걸 (OH MY GIRL)                              Dun Dun Dance  댄스
# 9              브레이브걸스                               롤린 (Rollin')  댄스
# 10                아이유                                  Celebrity  댄스
# 11        STAYC(스테이씨)                                       ASAP  댄스
# 12        STAYC(스테이씨)                           색안경 (STEREOTYPE)  댄스
# 13              방탄소년단  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  댄스
# 14          ITZY (있지)                                       LOCO  댄스
# 15             브레이브걸스                      치맛바람 (Chi Mat Ba Ram)  댄스
# 16       TWICE (트와이스)                               Alcohol-Free  댄스
# 17          BLACKPINK                             Lovesick Girls  댄스
# 18             브레이브걸스                             운전만해 (We Ride)  댄스
# 19        라붐 (LABOUM)                                      상상더하기  댄스
# 20                아이유                                어푸 (Ah puh)  댄스
# 21                양요섭      LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)  댄스
# 22  오마이걸 (OH MY GIRL)                                    Dolphin  댄스
#
#            발매일
# 0   2021.07.09
# 1   2021.05.17
# 2   2021.05.21
# 3   2021.07.06
# 4   2021.08.16
# 5   2020.08.24
# 6   2021.08.02
# 7   2021.03.25
# 8   2021.05.10
# 9   2017.03.07
# 10  2021.03.25
# 11  2021.04.08
# 12  2021.09.06
# 13  2019.04.12
# 14  2021.09.24
# 15  2021.06.17
# 16  2021.06.09
# 17  2020.10.02
# 18  2020.08.14
# 19  2016.04.06
# 20  2021.03.25
# 21  2021.03.05
# 22  2020.04.27

# %%
#최근 발매일순으로 정렬
song_df.loc[song_df['장르'] == '댄스',['가수','곡명','장르','발매일']]\
.sort_values(by='발매일',ascending=False).reset_index(drop=True)
# Out:
#                    가수                                         곡명  장르  \
# 0           ITZY (있지)                                       LOCO  댄스
# 1         STAYC(스테이씨)                           색안경 (STEREOTYPE)  댄스
# 2   Red Velvet (레드벨벳)                                   Queendom  댄스
# 3                 전소미                                  DUMB DUMB  댄스
# 4               방탄소년단                        Permission to Dance  댄스
# 5        태연 (TAEYEON)                                    Weekend  댄스
# 6              브레이브걸스                      치맛바람 (Chi Mat Ba Ram)  댄스
# 7        TWICE (트와이스)                               Alcohol-Free  댄스
# 8               방탄소년단                                     Butter  댄스
# 9               aespa                                 Next Level  댄스
# 10  오마이걸 (OH MY GIRL)                              Dun Dun Dance  댄스
# 11        STAYC(스테이씨)                                       ASAP  댄스
# 12                아이유                                  Celebrity  댄스
# 13                아이유                                        라일락  댄스
# 14                아이유                                어푸 (Ah puh)  댄스
# 15                양요섭      LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)  댄스
# 16          BLACKPINK                             Lovesick Girls  댄스
# 17              방탄소년단                                   Dynamite  댄스
# 18             브레이브걸스                             운전만해 (We Ride)  댄스
# 19  오마이걸 (OH MY GIRL)                                    Dolphin  댄스
# 20              방탄소년단  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  댄스
# 21             브레이브걸스                               롤린 (Rollin')  댄스
# 22        라붐 (LABOUM)                                      상상더하기  댄스
#
#            발매일
# 0   2021.09.24
# 1   2021.09.06
# 2   2021.08.16
# 3   2021.08.02
# 4   2021.07.09
# 5   2021.07.06
# 6   2021.06.17
# 7   2021.06.09
# 8   2021.05.21
# 9   2021.05.17
# 10  2021.05.10
# 11  2021.04.08
# 12  2021.03.25
# 13  2021.03.25
# 14  2021.03.25
# 15  2021.03.05
# 16  2020.10.02
# 17  2020.08.24
# 18  2020.08.14
# 19  2020.04.27
# 20  2019.04.12
# 21  2017.03.07
# 22  2016.04.06

# %%
#모든행과 Slicing을 사용하여 가수 부터 발매일까지
song_df.loc[:,'가수':'발매일'].head()
# Out:
#               가수                            앨범         발매일
# 0  The Kid LAROI                          Stay  2021.07.09
# 1            이무진                           신호등  2021.05.14
# 2       Coldplay                   My Universe  2021.09.24
# 3    디핵 (D-Hack)                OHAYO MY NIGHT  2020.06.20
# 4          방탄소년단  Butter / Permission to Dance  2021.07.09

# %%
### iloc[] 사용
#행의 인덱스가 0부터 5까지, 열의 인덱스가 0:4
song_df.iloc[0:5, 0:4]
# Out:
#                     곡명             가수                            앨범  \
# 0                 STAY  The Kid LAROI                          Stay
# 1                  신호등            이무진                           신호등
# 2          My Universe       Coldplay                   My Universe
# 3       OHAYO MY NIGHT    디핵 (D-Hack)                OHAYO MY NIGHT
# 4  Permission to Dance          방탄소년단  Butter / Permission to Dance
#
#           발매일
# 0  2021.07.09
# 1  2021.05.14
# 2  2021.09.24
# 3  2020.06.20
# 4  2021.07.09

# %%
song_df.columns
# Out:
# Index(['곡명', '가수', '앨범', '발매일', '장르', '좋아요', '가사'], dtype='object')

# %%
like_max_value = song_df['좋아요'].max()
print(like_max_value)
# Out:
# 549192

# %%
song_df.loc[song_df['좋아요'] == like_max_value]
# Out:
#     곡명     가수                    앨범         발매일    장르     좋아요  \
# 45  봄날  방탄소년단  YOU NEVER WALK ALONE  2017.02.13  랩/힙합  549192
#
#                                                    가사
# 45  보고 싶다이렇게 말하니까 더 보고 싶다너희 사진을 보고 있어도보고 싶다너무 야속한 ...

# %%
like_min_value = song_df['좋아요'].min()
song_df.loc[song_df['좋아요'] == like_min_value]
# Out:
#             곡명   가수                              앨범         발매일   장르   좋아요  \
# 92  전화 한 번 못하니  신예영  전화 한 번 못하니 (너에게 하고 싶은 말 X 신예영)  2021.09.26  발라드  4683
#
#                                                    가사
# 92  전화 한 번 못하니 벌써 날 잊어버렸니아님 이제 내 번호조차도 기억 못 하니잘 지내...

# %% [markdown]
# ### 100곡의 Song 정보가 포함된 데이터프레임 객체를 DB에 저장
# * pymysql 과 sqlalchemy 를 사용한다.

# %%
# !pip show sqlalchemy
# Out:
# Name: SQLAlchemy
# Version: 1.3.20
# Summary: Database Abstraction Library
# Home-page: http://www.sqlalchemy.org
# Author: Mike Bayer
# Author-email: mike_mp@zzzcomputing.com
# License: MIT
# Location: c:\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
# !pip show pymysql
# Out:
# Name: PyMySQL
# Version: 1.0.2
# Summary: Pure Python MySQL Driver
# Home-page: https://github.com/PyMySQL/PyMySQL/
# Author: yutaka.matsubara
# Author-email: yutaka.matsubara@gmail.com
# License: "MIT"
# Location: c:\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
print(con)

#DataFrame의 to_sql() 함수로 dataframe 객체를 Table로 저정
song_df.to_sql(name='songs', con=engine, if_exists='replace', index=False)
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x0000020B088592B0>

# %%
#기존 DataFrame 객체의 복사본을 생성함
#table_df = song_df2  #두개의 DataFrame의 주소가 같아지므로 이와 같이 복사하면 않됨
table_df = song_df2.copy()
table_df.head()
# Out:
#               곡명             가수                           앨범         발매일  \
# 0         Savage          aespa  Savage - The 1st Mini Album  2021.10.05
# 1           STAY  The Kid LAROI                         Stay  2021.07.09
# 2    My Universe       Coldplay                  My Universe  2021.09.24
# 3            신호등            이무진                          신호등  2021.05.14
# 4  낙하 (with 아이유)      AKMU (악뮤)                 NEXT EPISODE  2021.07.26
#
#      장르     좋아요                                                 가사
# 0    댄스   51107  Oh my gosh!Don't you know I’m a Savage?I’m a K...
# 1   POP  165140  I do the same thing I told youthat I never wou...
# 2   POP  104769  You, you are my universe andI just want to put...
# 3  록/메탈  222188  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 4  록/메탈  133812  말했잖아 언젠가이런 날이 온다면난 널 혼자 내버려두지 않을 거라고 죄다 낭떠러지야,...

# %%
#컬럼명을 변경하기
table_df.columns = ['title','singer','album','release_date','genre','likes','lyric']
table_df.head(2)
# Out:
#     title         singer                        album release_date genre  \
# 0  Savage          aespa  Savage - The 1st Mini Album   2021.10.05    댄스
# 1    STAY  The Kid LAROI                         Stay   2021.07.09   POP
#
#     likes                                              lyric
# 0   51107  Oh my gosh!Don't you know I’m a Savage?I’m a K...
# 1  165140  I do the same thing I told youthat I never wou...

# %%
table_df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
#index가 1부터 시작되도록 변경

import numpy as np

#index 값을 변경하기
table_df.index = np.arange(1,len(table_df)+1)
table_df.head(2)
# Out:
#     title         singer                        album release_date genre  \
# 1  Savage          aespa  Savage - The 1st Mini Album   2021.10.05    댄스
# 2    STAY  The Kid LAROI                         Stay   2021.07.09   POP
#
#     likes                                              lyric
# 1   51107  Oh my gosh!Don't you know I’m a Savage?I’m a K...
# 2  165140  I do the same thing I told youthat I never wou...

# %%
table_df.tail(3)
# Out:
#                 title             singer                     album  \
# 98          여전히 아름다운지                세븐틴  슬기로운 의사생활 시즌2 OST Part 8
# 99            Dolphin  오마이걸 (OH MY GIRL)                   NONSTOP
# 100  12:45 (Stripped)              Etham          12:45 (Stripped)
#
#     release_date       genre   likes  \
# 98    2021.08.13  발라드, 국내드라마   45209
# 99    2020.04.27          댄스  192444
# 100   2018.10.26         POP  151390
#
#                                                  lyric
# 98   첨엔 혼자라는 게 편했지자유로운 선택과 시간에너의 기억을 지운 듯 했어정말 난 그런...
# 99   oh my god 타이밍이 참 얄미워오늘 같은 날 마주쳐 이게 뭐야머리는 엉망인 데...
# 100  It's 12 45 on a Tuesdayand I don't really care...

# %% [markdown]
# ### 컬럼명과 DataType을 변경해서 Table로 저장하기

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
print(con)

#['곡명', '가수', '앨범', '발매일', '장르', '가사']
#DataFrame의 to_sql() 함수로 dataframe 객체를 Table로 저정
table_df.to_sql(name='songs100', con=engine, if_exists='replace', index=True,\
              index_label='id',
              dtype={
                  'id':sqlalchemy.types.INTEGER(),
                  'title':sqlalchemy.types.VARCHAR(200),
                  'singer':sqlalchemy.types.VARCHAR(100),
                  'album':sqlalchemy.types.VARCHAR(100),
                  'release_date':sqlalchemy.DATE,
                  'genre':sqlalchemy.types.VARCHAR(100),
                  'likes':sqlalchemy.types.BigInteger,
                  'lyric':sqlalchemy.types.VARCHAR(2500)
              })
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x000001F53928C7F0>

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')

from sqlalchemy.sql import text
with engine.connect() as con:
    #insert할 데이터
    data = ( { "title": "노래", "singer": "둘리","album":"둘리앨범","release_date":"2021-07-09",
              "genre":"동요","likes":1000,"lyric":"aa" }, )
    #id컬럼을 auto_increment로 수정
    stmt = text("""alter table songs100 modify id int auto_increment;""")
    
    statement = text("""INSERT INTO songs100 (title,singer,album,release_date,genre,likes,lyric) 
    VALUES (:title, :singer, :album, :release_date, :genre, :likes, :lyric)""")

    for line in data:
        con.execute(stmt)
        con.execute(statement, **line)

# %% [markdown]
# ### Table을 DataFrame 객체로 변환하기

# %%
import pymysql
import sqlalchemy

#pymysql과 sqlalchemy 를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                      encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결 
con = engine.connect()
# Table을 DataFrame으로 가져오기
songs100_df=pd.read_sql_table('songs100',con)

#DB 연결 종료
con.close()

songs100_df.head()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#    id          title         singer                        album release_date  \
# 0   1         Savage          aespa  Savage - The 1st Mini Album   2021-10-05
# 1   2           STAY  The Kid LAROI                         Stay   2021-07-09
# 2   3    My Universe       Coldplay                  My Universe   2021-09-24
# 3   4            신호등            이무진                          신호등   2021-05-14
# 4   5  낙하 (with 아이유)      AKMU (악뮤)                 NEXT EPISODE   2021-07-26
#
#   genre   likes                                              lyric
# 0    댄스   51107  Oh my gosh!Don't you know I’m a Savage?I’m a K...
# 1   POP  165140  I do the same thing I told youthat I never wou...
# 2   POP  104769  You, you are my universe andI just want to put...
# 3  록/메탈  222188  이제야 목적지를 정했지만가려한 날 막아서네 난 갈 길이 먼데새빨간 얼굴로 화를 냈던...
# 4  록/메탈  133812  말했잖아 언젠가이런 날이 온다면난 널 혼자 내버려두지 않을 거라고 죄다 낭떠러지야,...

# %%
def search_album(keyword):
    sql = """select * from songs100 where album like %s;"""

    import pymysql
    import sqlalchemy

    #pymysql과 sqlalchemy 를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                          encoding='utf-8')
    print(engine)
    #Engine을 사용해서 DB에 연결 
    con = engine.connect()
    
    #query실행한 결과를 DataFrame 객체로 변환하기
    album_df = pd.read_sql_query(sql, con=con, params=('%' + keyword + '%',))
    print(len(album_df))
    con.close()
    return album_df

# %%
result = search_album('OST')
result
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# 10
#    id                                  title   singer  \
# 0  18                                   좋아좋아      조정석
# 1  27                                  비와 당신      이무진
# 2  49                             가을 우체국 앞에서      김대명
# 3  51                                내 손을 잡아      아이유
# 4  59                   내 기억 속에 남아 있는 그대 모습은       산들
# 5  70  모든 날, 모든 순간 (Every day, Every Moment)       폴킴
# 6  76                                    아로하      조정석
# 7  80               흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야      장범준
# 8  91                 이젠 잊기로 해요 (Drama Ver.)  미도와 파라솔
# 9  98                              여전히 아름다운지      세븐틴
#
#                        album release_date        genre   likes  \
# 0   슬기로운 의사생활 시즌2 OST Part 5   2021-07-16   발라드, 국내드라마   73793
# 1   슬기로운 의사생활 시즌2 OST Part 1   2021-06-18  록/메탈, 국내드라마   88735
# 2   슬기로운 의사생활 시즌2 OST Part 2   2021-06-25   발라드, 국내드라마   47470
# 3          최고의 사랑 OST Part.4   2011-05-25   발라드, 국내드라마  170348
# 4         갯마을 차차차 OST Part 6   2021-10-03  록/메탈, 국내드라마   12673
# 5    '키스 먼저 할까요?' OST Part.3   2018-03-20   발라드, 국내드라마  377028
# 6       슬기로운 의사생활 OST Part 3   2020-03-27   발라드, 국내드라마  228981
# 7          멜로가 체질 OST Part 3   2019-08-23  록/메탈, 국내드라마  294101
# 8  슬기로운 의사생활 시즌2 OST Special   2021-07-30  록/메탈, 국내드라마   28700
# 9   슬기로운 의사생활 시즌2 OST Part 8   2021-08-13   발라드, 국내드라마   45209
#
#                                                lyric
# 0  처음 널 만나는 날노란 세 송이 장미를 들고룰루랄라 신촌을 향하는내 가슴은 마냥 두...
# 1  이젠 당신이 그립지 않죠보고 싶은 마음도 없죠사랑한 것도 잊혀 가네요조용하게알 수 ...
# 2  가을 우체국 앞에서그대를 기다리다노오란 은행잎들이바람에 날려가고지나는 사람들 같이저...
# 3  느낌이 오잖아 떨리고 있잖아언제까지 눈치만 볼 거니네 맘을 말해봐 딴청 피우지 말란...
# 4  눈을 감고 불어온 밤바람에찬찬히 흩날린 머리칼을 맡기며감겨오는 옷자락 소리에너와 손...
# 5  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 6  어두운 불빛아래 촛불 하나와인 잔에 담긴 약속하나항상 너의 곁에서 널 지켜줄거야날 ...
# 7  흔들리는 꽃들 속에서네 샴푸향이 느껴진거야스쳐지나간건가 뒤돌아보지만그냥 사람들만 보...
# 8  이젠 잊기로 해요이젠 잊어야 해요사람 없는 성당에서 무릎 꿇고기도했던걸 잊어요이젠 ...
# 9  첨엔 혼자라는 게 편했지자유로운 선택과 시간에너의 기억을 지운 듯 했어정말 난 그런...

# %%
def search_song(singer,title):
    sql = """select * from songs100 where singer like %s or title like %s;"""
    
    import pymysql
    import sqlalchemy

    #pymysql과 sqlalchemy 를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',\
                          encoding='utf-8')
    print(engine)
    #Engine을 사용해서 DB에 연결 
    con = engine.connect()
    
    singer = f'%{singer}%'
    title = f'%{title}%'
    
    result = pd.read_sql_query(sql,con=con, params=(singer,title))
    
    con.close()
    
    return result

# %%
result_df = search_song('김','a')
result_df
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#     id                                              title             singer  \
# 0    1                                             Savage              aespa
# 1    2                                               STAY      The Kid LAROI
# 2    7                                     OHAYO MY NIGHT        디핵 (D-Hack)
# 3    8                                Permission to Dance              방탄소년단
# 4   14                                         Bad Habits         Ed Sheeran
# 5   15                                           Dynamite              방탄소년단
# 6   16             Peaches (Feat. Daniel Caesar & Giveon)      Justin Bieber
# 7   37                                      Dun Dun Dance  오마이걸 (OH MY GIRL)
# 8   39                   찰나가 영원이 될 때 (The Eternal Moment)       마크툽 (MAKTUB)
# 9   40                                               ASAP        STAYC(스테이씨)
# 10  42  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...       David Guetta
# 11  43       Savage Love (Laxed - Siren Beat) (BTS Remix)          Jawsh 685
# 12  45      사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)                호미들
# 13  47          작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)              방탄소년단
# 14  49                                         가을 우체국 앞에서                김대명
# 15  53                                        Off My Face      Justin Bieber
# 16  64                                 빨간 립스틱 (Feat. 윤미래)                이하이
# 17  66                              치맛바람 (Chi Mat Ba Ram)             브레이브걸스
# 18  67                                       Alcohol-Free       TWICE (트와이스)
# 19  70              모든 날, 모든 순간 (Every day, Every Moment)                 폴킴
# 20  74           오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)       마크툽 (MAKTUB)
# 21  85                        에잇(Prod.&Feat. SUGA of BTS)                아이유
# 22  86                                        어푸 (Ah puh)                아이유
# 23  88              LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)                양요섭
# 24  91                             이젠 잊기로 해요 (Drama Ver.)            미도와 파라솔
# 25  92                                      Gloomy Sunday                 폴킴
# 26  94                      비 오는 날 듣기 좋은 노래 (Feat. Colde)   에픽하이 (EPIK HIGH)
# 27  97                                             GLASSY                조유리
#
#                                            album release_date           genre  \
# 0                    Savage - The 1st Mini Album   2021-10-05              댄스
# 1                                           Stay   2021-07-09             POP
# 2                                 OHAYO MY NIGHT   2020-06-20            랩/힙합
# 3                   Butter / Permission to Dance   2021-07-09              댄스
# 4                                        Shivers   2021-08-19             POP
# 5                     Dynamite (DayTime Version)   2020-08-24              댄스
# 6                                        Justice   2021-03-19             POP
# 7                                  Dear OHMYGIRL   2021-05-10              댄스
# 8                    Red Moon : Beyond The Light   2021-09-19  R&B/Soul, 인디음악
# 9                                        STAYDOM   2021-04-08              댄스
# 10                                        Listen   2014-11-25          일렉트로니카
# 11  Savage Love (Laxed - Siren Beat) [BTS Remix]   2020-10-02             POP
# 12                                     사이렌 Remix   2021-03-20            랩/힙합
# 13                     MAP OF THE SOUL : PERSONA   2019-04-12              댄스
# 14                      슬기로운 의사생활 시즌2 OST Part 2   2021-06-25      발라드, 국내드라마
# 15                                       Justice   2021-03-19             POP
# 16                                        4 ONLY   2021-09-09        R&B/Soul
# 17                                  Summer Queen   2021-06-17              댄스
# 18                                 Taste of Love   2021-06-09              댄스
# 19                       '키스 먼저 할까요?' OST Part.3   2018-03-20      발라드, 국내드라마
# 20                    Red Moon : To You My Light   2019-06-09  R&B/Soul, 인디음악
# 21                                            에잇   2020-05-06            록/메탈
# 22                          IU 5th Album 'LILAC'   2021-03-25              댄스
# 23         LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)   2021-03-05              댄스
# 24                     슬기로운 의사생활 시즌2 OST Special   2021-07-30     록/메탈, 국내드라마
# 25                                        찬란한 계절   2021-10-07        R&B/Soul
# 26                               비 오는 날 듣기 좋은 노래   2021-06-29            랩/힙합
# 27                                        GLASSY   2021-10-07              댄스
#
#      likes                                              lyric
# 0    51107  Oh my gosh!Don't you know I’m a Savage?I’m a K...
# 1   165140  I do the same thing I told youthat I never wou...
# 2   141510  너를 사랑하고 있어너를 사랑하고 있어자기야 날 사랑해주면 안 될까말처럼 쉽지는 않은...
# 3   180119  It’s the thought of being youngWhen your heart...
# 4    76760  Every time you come aroundyou know I can’t say...
# 5   424630  Cos ah ahI’m in the stars tonightSo watch me b...
# 6   201846  I got my peaches out in GeorgiaOh yeah shitI g...
# 7   143982  Dun Dun Dance Dun Dun DanceDun Dun DanceJust d...
# 8    19466  서로를 향한 마음이우주의 작은 뭉쳐짐이라면이 아름다운 기억이 흩어져도사라지진 않을 ...
# 9   129135  STAYC girls it’s going downTime is running boy...
# 10   44187
# 11  187602  Savage loveDid somebody did somebodyBreak your...
# 12  113877  울려댔어 사이렌텅 빈 길거리엔도망치다 흘린 칼자루와 피가 흥건해우리 그때 어릴땐뭘 ...
# 13  429585  모든 게 궁금해How’s your dayOh tell me뭐가 널 행복하게 하는지O...
# 14   47470  가을 우체국 앞에서그대를 기다리다노오란 은행잎들이바람에 날려가고지나는 사람들 같이저...
# 15   80571  One touch and you got me stonedHigher than I'v...
# 16   20558  오늘 밤은 이 분위기에 취해아무런 생각 없이 groove it고민하지 마 just ...
# 17   93265  You know what it isB. girls are back, Brave So...
# 18   76539  너와 있을 땐 내게신기한 변화가 있는데자꾸 미소 짓게 돼아무 일도 없는데자꾸 마법에...
# 19  377028  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 20  247158  별빛이 내린 밤그 풍경 속 너와 나날 새롭게 하는따뜻하게 만드는니 눈빛 니 미소영원...
# 21  367989  So are you happy nowFinally happy now are you뭐...
# 22  103750  I’m such a good surfer가라앉지 않기비틀 비 비틀 거리다가 풍덩 u...
# 23  103238  참 많이 궁금해전부 다 궁금해왜 잠이 안 오고 네 얼굴만 보여나도 궁금해이 맘이 궁...
# 24   28700  이젠 잊기로 해요이젠 잊어야 해요사람 없는 성당에서 무릎 꿇고기도했던걸 잊어요이젠 ...
# 25    2261  시간을 잃은 Time가득 쌓인 Dishes바닥엔 옷더미마르지 않은 양말TV 소리에나...
# 26   63687  비가 오고네가 생각나비가 오고또 비가 오고슬픈 음악이 흐르면옛 노래처럼네가 생각나네...
# 27    9376  기분이 들떠 Like a star like a star 걸음에 시선이 쏟아져 아닌척...
