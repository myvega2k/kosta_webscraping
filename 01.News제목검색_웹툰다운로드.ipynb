# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.25.1
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires: chardet, certifi, idna, urllib3
# Required-by: Sphinx, jupyterlab-server, conda, conda-repo-cli, conda-build, anaconda-project, anaconda-client

# %% [markdown]
# ### 네이버 뉴스 제목 가져오기
# * user-agent 헤더값을 반드시 설정해야 함
# * user-agent 헤더는 브라우저에 대한 정보

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = 'https://news.naver.com/'
req_header = {
    #browser 정보
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36'
}

res = requests.get(url, headers=req_header)

print(type(res))
print(res.status_code)
print(res.ok)
print('응답 헤더 = ', res.headers)
print('content-type 헤더 =', res.headers['content-type'])
print('요청 헤더 = ', res.request.headers)
# Out:
# <class 'requests.models.Response'>
# 200
# True
# 응답 헤더 =  {'date': 'Thu, 07 Oct 2021 04:22:24 GMT', 'cache-control': 'no-cache', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'set-cookie': 'JSESSIONID=BE90336175A13F461FD03B549C74F970; Path=/main; HttpOnly', 'content-language': 'ko-KR', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'transfer-encoding': 'chunked', 'content-type': 'text/html;charset=EUC-KR', 'referrer-policy': 'unsafe-url', 'server': 'nfront'}
# content-type 헤더 = text/html;charset=EUC-KR
# 요청 헤더 =  {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
if res.ok:
    #소스보기 했을 때의 text
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    #soup
    print(len(soup.select("a[href*='read.naver']")))
    atag_list = soup.select("a[href*='read.naver']")
    #<class 'bs4.element.ResultSet'>
    #print(type(atag_list))

    for atag in atag_list:
        #<class 'bs4.element.Tag'>
        #print(type(atag))
        title = atag.text.strip()
        #print(title.strip())
        href = urljoin(url, atag['href'])
        print(title, href)
# Out:
# <class 'requests.models.Response'>
# 200
# True
# 199
# '김건희 연루 의혹' 도이치모터스 사건 관계자 … https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=102&oid=055&aid=0000925587
# SKIET, 유럽 첫 분리막 생산기업 됐다…폴란드… https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=018&aid=0005053997
# '삼성 개발자 콘퍼런스' 2년 만에 열린다…차세대 기술 논의 https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=421&aid=0005642570
# '판도라 상자' 김웅 녹취록 풀릴까…조성은, 정보공개 청구 https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=100&oid=057&aid=0001612593
# 뉴욕증시, 부채한도 협상 기대감에 상승…비트코인 5.5만달러 돌파[모닝브리핑] https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=015&aid=0004613263
# 미국 최대 완성차 업체 GM이 전세계 투자자들을 끌어모으고 던진 메시지는? https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004861520
# 8월 경상수지 75.1억달러 흑자…서비스수지 흑자 `역대 2위`[이데일리N] https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=018&aid=0005053982
# ...

# %% [markdown]
# ### 네이버 웹툰 이미지 다운로드
# * referer 라는 헤더값을 설정이 필요함
# * binary data는 content 속성(property 사용)

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=748105&no=113&amp;weekday=thu'
}
image_urls = [
    'https://image-comic.pstatic.net/webtoon/748105/113/20210926000844_2263ea551cb1dfdaebeed091570d4bf8_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/748105/113/20210926000844_2263ea551cb1dfdaebeed091570d4bf8_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/748105/113/20210926000844_2263ea551cb1dfdaebeed091570d4bf8_IMAG01_3.jpg'
]
for image_url in image_urls:
    res = requests.get(image_url, headers=req_header)
    #print(res.status_code)
    if res.ok:
        img_data=res.content
        file_name = os.path.basename(image_url)
        with open(file_name,'wb') as file:
            print(f'파일명은 {file_name} 이고, 파일 Size는 {len(img_data)}(bytes)')
            file.write(img_data)
# Out:
# 파일명은 20210926000844_2263ea551cb1dfdaebeed091570d4bf8_IMAG01_1.jpg 이고, 파일 Size는 108112(bytes)
# 파일명은 20210926000844_2263ea551cb1dfdaebeed091570d4bf8_IMAG01_2.jpg 이고, 파일 Size는 91525(bytes)
# 파일명은 20210926000844_2263ea551cb1dfdaebeed091570d4bf8_IMAG01_3.jpg 이고, 파일 Size는 150754(bytes)

# %% [markdown]
# ### 파일 업로드 하기
# * http://httpbin.org/post 요청으로 파일을 업로드 하기
# * requests의 post 함수를 사용하고, files 속성을 설정한다.

# %%
import requests

file_data = {
    'img1': open('f1.jpg','rb'),
    'img2': open('f2.jpg','rb'),
    'img3': open('f3.jpg','rb')
}
url = 'http://httpbin.org/post'
res = requests.post(url, files=file_data)
print(res.status_code)
res.json()['files']['img1']
# Out:
# 200
# 'data:application/octet-stream;base64,...'
