# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.25.1
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: c:\users\vega2\anaconda3\lib\site-packages
# Requires: urllib3, chardet, certifi, idna
# Required-by: Sphinx, jupyterlab-server, conda, conda-repo-cli, conda-build, anaconda-project, anaconda-client

# %% [markdown]
# ### 네이버 뉴스 제목 가져오기
# * user-agent 헤더값을 반드시 설정해야 함
# * user-agent 헤더는 브라우저에 대한 정보

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://news.naver.com/'
req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36'
}

res = requests.get(url, headers=req_header)
print(type(res))
print(res.status_code)
print(res.ok)

#소스보기 했을 때의 text
html = res.text
soup = BeautifulSoup(html, 'html.parser')
#soup
# Out:
# <class 'requests.models.Response'>
# 200
# True
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <title>네이버 뉴스</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210915_001744/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210915_001744/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210915_001744/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20210915_001744/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='home';
# var _MAIN_NEWS_SECTION_ID='100';
# var ccsrv='cc.naver.com';
# var g_ssc='news.home';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Thu Oct 07 11:30:02 KST 2021";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210915_001744/js/news.service.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body class="chrome">
# <div id="wrap">
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(ST A.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com">뉴스스탠드</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li class="lnb_menu_home on"><a class="nclicks(LNB.home)" href="/main/home.naver"><span class="tx">뉴스홈</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(LNB.flash)" href="/main/list.naver?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx">속보</span></a></li>
# <li><a class="nclicks(LNB.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(LNB.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(LNB.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(LNB.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(LNB.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(LNB.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(LNB.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(LNB.pho)" href="/main/photo/index.naver?mid=pho"><span class="tx">포토</span> </a></li>
# <li><a class="nclicks(LNB.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹뉴스</span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="home_timelate">
# <div class="ht_head">
# <ul class="ht_tabmnu">
# <li id="ht_tabmnu_0">
# <a href="#" title="신문 헤드라인">신문 헤드라인<span class="ht_ico"></span></a>
# </li>
# <li id="ht_tabmnu_1">
# <a href="#" title="저녁 방송 뉴스">저녁 방송 뉴스<span class="ht_ico"></span></a>
# </li>
# </ul>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.naver" title="팩트체크">팩트체크
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="https://media.naver.com/channel/settings" target="_blank" title="언론사 설정">언론사 설정
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# </ul>
# </div>
# <div class="ht_comp ht_paperheadline" id="paperHeadlineRolling" style="display: none;">
# <h3 class="blind">신문 헤드라인</h3>
# <ul class="ht_ph_lst" style="display: none;">
# <!-- 헤드라인 데이터 동적삽입 <li> -->
# </ul>
# <div class="ht_nodata_all" style="display: none;">발행된 종이신문이 없거나 신문게재 정보가 입력되지 않았습니다.</div>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev)" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <div class="ht_comp ht_eveningnews" id="eveningNewsRolling" style="display: none;">
# <h3 class="blind">저녁 방송 뉴스</h3>
# <ul class="ht_ph_lst">
# <!-- 저녁방송뉴스 동적삽입 <li> -->
# </ul>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev);" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <script type="text/javascript">
# _oTopComponentData = {
# "open" : "N",
# "target" : "headlineList",
# "headlineList" : [
# {
# "officeId" : "030",
# "officeName" : "전자신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/030/2017/01/05/logo_030_1_20170105110505.gif' width='206' height='30' alt='전자신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/030/2021/10/07/2973744.jpg?type=nf80_54",
# "title" : "삼성, 2025년 2나노 반도체 양산...3세대 GAA 적용",
# "summary" : "삼성전자가 차세대 트랜지스터 구조인 \'게이트올어라운드(GAA)\'를 적용한 2나노 반도체 공정을 2025년부터 양산한다. TSMC와 인텔보다 1년여 늦은 일정이지만, 3나노 공정에 우선 적용해 얻은 양산 기술을 활용해",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "032",
# "officeName" : "경향신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/032/2017/01/05/logo_032_1_20170105110505.gif' width='206' height='30' alt='경향신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/032/2021/10/06/3102137.jpg?type=nf80_54",
# "title" : "김웅·조성은 통화 녹취록 복구 ‘확인’…“고발장, 꼭 대검 민원실에 접수해야”",
# "summary" : "[경향신문]  공수처, 고발 사주 의혹 수사 정점식 의원실 압수수색 박지원 국정원장은 입건  윤석열 전 검찰총장 재직 시절 검찰의 ‘고발 사주’ 의혹을 수사 중인 고위공직자범죄수사처(공수처)가 의혹 제보자인 조성은씨",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "011",
# "officeName" : "서울경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/011/2017/01/05/logo_011_1_20170105110505.gif' width='206' height='30' alt='서울경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/011/2021/10/06/3970190.jpg?type=nf80_54",
# "title" : "中원료 끊긴 반도체부품사···\'셧다운 위기\' 현실화",
# "summary" : "[서울경제] 중국 전력난으로 촉발된 국내 반도체·디스플레이 소재·부품·장비(소부장) 기업들의 원료 수급난 우려가 현실화하고 있다. 중국 정부가 현지 기업에 전력난을 이유로 공장 가동률을 대폭 낮추라고 명령하면서 반도",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "353",
# "officeName" : "중앙SUNDAY",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/03/17/logo_353_1_20180317103917.png' width='206' height='30' alt='중앙SUNDAY' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "277",
# "officeName" : "아시아경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/277/2017/01/05/logo_277_1_20170105110505.gif' width='206' height='30' alt='아시아경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/277/2021/10/07/4979782.jpg?type=nf80_54",
# "title" : "바이든·시진핑 연내 첫 정상회담(종합)",
# "summary" : "조 바이든 미국 대통령과 시진핑 중국 국가주석이 화상으로 첫 정상회담에 나선다. 바이든 정부 출범 후 첫 회담이 열리는 만큼 미·중 갈등에 새로운 전기가 마련될지 주목된다. 대북 제재 완화 및 종전선언 등 북한 관련",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "014",
# "officeName" : "파이낸셜뉴스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/014/2017/01/05/logo_014_1_20170105110505.gif' width='206' height='30' alt='파이낸셜뉴스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/014/2021/10/06/4719351.jpg?type=nf80_54",
# "title" : "금융시장 \'트리플 약세\'.. 코스피 2900선도 위협",
# "summary" : "\'국고채(3년물) 2년4개월여 만에 최고치\' \'코스피 연중 최저치\' \'원·달러 환율 1년2개월 만에 최고치\' 전 세계적으로 인플레이션에 대한 우려가 커지고 있는 가운데 국내 금융시장이 공포로 얼어붙고 있다. 전문가들",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "015",
# "officeName" : "한국경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/015/2017/01/05/logo_015_1_20170105110505.gif' width='206' height='30' alt='한국경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/015/2021/10/06/4613014.jpg?type=nf80_54",
# "title" : "\"디지털 전환, 5년이 데드라인\"",
# "summary" : "구글, 애플, 페이스북 등의 미국 실리콘밸리 본사는 아직 텅텅 비어 있다. 수십만 명의 빅테크 임직원은 코로나19 팬데믹 이후 2년 가까이 원격근무 중이다. ‘효율성이 떨어지고 대형 프로젝트 진행이 쉽지 않을 것’이",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "016",
# "officeName" : "헤럴드경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/016/2017/01/05/logo_016_1_20170105110505.gif' width='206' height='30' alt='헤럴드경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/016/2021/10/07/1896374.jpg?type=nf80_54",
# "title" : "美 ‘최고의 첨단기술 채택·실현 자동차’...제네시스, 캐딜락·벤츠 제치고 1위 질주",
# "summary" : "현대자동차 제네시스가 미국 내에서 가장 최첨단 기술을 잘 구현한 자동차 브랜드에 처음으로 이름을 올렸다. 전 라인업이 최고 안전 등급을 획득한 데 이어 브랜드 가치를 높이는 계기가 될 것으로 보인다. 6일(현지시간)",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "018",
# "officeName" : "이데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/018/2017/01/05/logo_018_1_20170105110505.gif' width='206' height='30' alt='이데일리' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/018/2021/10/06/5053624.jpg?type=nf80_54",
# "title" : "\'마지막 돈줄\' 쥐어짜 버티는데…정부는 \"손실보상 전액 어렵다\"",
# "summary" : "연도별 노란우산 누적 대출 금액(그래프=문승용 기자) [이데일리 김호준 기자] 코로나19 사태 장기화로 소상공인 ‘마지막 보루’로 일컬어지는 노란우산공제 중도대출이 2년 만에 두 배가량 급증한 것으로 나타났다. 이렇",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "081",
# "officeName" : "서울신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/081/2017/01/05/logo_081_1_20170105110505.gif' width='206' height='30' alt='서울신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/081/2021/10/06/3220575.jpg?type=nf80_54",
# "title" : "김웅 “고발장 보내줄 테니 대검에 접수하라”",
# "summary" : "윤석열 전 검찰총장이 연루된 ‘고발 사주’ 의혹을 수사 중인 고위공직자범죄수사처가 김웅(왼쪽) 국민의힘 의원과 공익신고자인 조성은(오른쪽)씨의 통화 내용이 담긴 녹취 파일을 복구한 것으로 알려졌다. 이 녹취 파일에는",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "082",
# "officeName" : "부산일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/082/2021/01/15/logo_082_1_20210115134425.png' width='206' height='30' alt='부산일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/082/2021/10/06/1122206.jpg?type=nf80_54",
# "title" : "‘국제관광도시 부산’ 이끌 스타기업 25곳 키운다",
# "summary" : "대한민국 1호 국제관광도시 부산이 2030부산월드엑스포 개최와 가덕신공항 개항이라는 호재를 앞두고 지역 관광 분야의 스타기업을 체계적으로 육성한다. 이들 관광 스타기업은 2030부산월드엑스포와 가덕신공항이라는 특수가",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "020",
# "officeName" : "동아일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/020/2017/01/05/logo_020_1_20170105110505.gif' width='206' height='30' alt='동아일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "野 “50억 약속그룹 6명”… 당사자들은 “사실무근”",
# "summary" : "국민의힘 박수영 의원이 6일 경기 성남시 대장동 개발 민간사업자인 화천대유자산관리(화천대유)로부터 50억 원을 받았거나 받기로 한 로비 대상 명단이라며 이른바 ‘50억 약속 클럽’ 명단 6명을 공개했다. 박 의원은 ",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "087",
# "officeName" : "강원일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/087/2021/01/15/logo_087_1_20210115134053.png' width='206' height='30' alt='강원일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/087/2021/10/07/863030.jpg?type=nf80_54",
# "title" : "춘천 조교리·물로리, 홍천 편입 가능성 커졌다",
# "summary" : "“면사무소 가려면 홍천·인제·양구 68㎞ 관통” 주민 수십년 고통 道 ‘영월 문산리→평창\' ‘경기 양평 삼산리→원주\' 편입 건의 속보=내년에 강원도 일부 시·군의 리(里) 지역이 타 지역으로 편입될 가능성이 제기되면",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "021",
# "officeName" : "문화일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/021/2017/01/05/logo_021_1_20170105110505.gif' width='206' height='30' alt='문화일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/021/2021/10/07/2487884.jpg?type=nf80_54",
# "title" : "가스·석탄값 급등 → 中·印 전력난 → 물가 폭등… ‘무서운 I’가 왔다",
# "summary" : "■ 글로벌 포커스 - 전세계 인플레이션 공포 블룸버그 원자재 현물지수 516.84로 사상 최고 기록 천연가스 129% 폭등하고 발전용 석탄값 두배로 올라 세계의 공장인 중국·인도 석탄값 폭등에 전력난 허덕 수출단가 ",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "088",
# "officeName" : "매일신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/088/2021/01/15/logo_088_1_20210115134127.png' width='206' height='30' alt='매일신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/088/2021/10/06/724579.jpg?type=nf80_54",
# "title" : "동부소방서·법원·검찰청 터 묶어 동대구벤처밸리 활성화",
# "summary" : "오는 2024년 이전이 확정된 대구 동부소방서와 수성구 범어동 법원·검찰청 개발 계획에 대한 관심이 높아지고 있다. 대구시는 동부소방서 부지를 법원검찰청 부지와 함께 활용하는 방안을 검토하는 것으로 확인됐다. 대구시",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "022",
# "officeName" : "세계일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/022/2017/01/05/logo_022_1_20170105110505.gif' width='206' height='30' alt='세계일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/022/2021/10/06/3625763.jpg?type=nf80_54",
# "title" : "[단독] ‘위례’ 사업변경 대장동팀 참여 길 터 줬다",
# "summary" : "성남도개공, 당초 자체 사업서 SPC 출자 민관합작으로 바꿔 野, 유동규 개입 가능성 제기 성남도개공 처장 檢 출석 김문기 성남도시개발공사 개발1처장이 6일 성남 대장지구 개발사업 특혜 의혹 관련 조사를 받기 위해 ",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "044",
# "officeName" : "코리아헤럴드",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/044/2017/01/05/logo_044_1_20170105110505.gif' width='206' height='30' alt='코리아헤럴드' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/044/2021/10/06/231207.jpg?type=nf80_54",
# "title" : "S. Korea’s housing prices see largest surge in 15 years",
# "summary" : "South Korea’s housing prices in the first nine months of this year spiked nearly 12 percent, surpassing the annual gains",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "023",
# "officeName" : "조선일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/023/2017/01/05/logo_023_1_20170105110505.gif' width='206' height='30' alt='조선일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/023/2021/10/06/3644711.jpg?type=nf80_54",
# "title" : "성남시의회 前의장도 화천대유 근무… 녹취록엔 “의장도 로비”",
# "summary" : "경기 성남시의회 의장을 지낸 최모(62)씨가 화천대유에 근무 중인 것으로 6일 확인됐다. 최씨는 이재명 경기지사가 성남시장이던 2012년부터 화천대유가 대장동 개발 사업에 참여하기 1년 전인 2014년까지 성남시의회",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "640",
# "officeName" : "코리아중앙데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/640/2021/05/17/logo_640_1_20210517192250.png' width='206' height='30' alt='코리아중앙데일리' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/640/2021/10/06/16893.jpg?type=nf80_54",
# "title" : "\'5 billion won\' club alleged in development scandal",
# "summary" : "A lawmaker from the main opposition party Wednesday released a list of bigwigs alleged to have been part of the \"5 billi",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "025",
# "officeName" : "중앙일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/31/logo_025_1_20210831104529.jpg' width='206' height='30' alt='중앙일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/025/2021/10/07/3140564.jpg?type=nf80_54",
# "title" : "\"대장동 개발 초과이익 환수해야\" 실무진 의견 다 묵살됐다",
# "summary" : "2015년 경기도 성남시 대장동 개발 사업 당시 성남도시개발공사가 민간사업자 모집을 위한 공모지침서를 만들 때부터 ‘초과 이익 환수를 검토해야 한다’는 의견이 나왔으나 묵살됐다는 증언이 나왔다. 6일 열린 성남시의회",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "005",
# "officeName" : "국민일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/005/2017/01/05/logo_005_1_20170105110505.gif' width='206' height='30' alt='국민일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/005/2021/10/07/1475191.jpg?type=nf80_54",
# "title" : "檢 대장동 의혹 줄소환… 로비·특혜 투트랙 수사",
# "summary" : "성남시 대장동 개발사업 특혜 의혹을 수사하는 검찰이 이성문 전 화천대유자산관리(화천대유) 대표와 관계사인 천화동인 1호의 이한성 대표를 불러 조사했다. 사업자 선정에 관여한 김문기 성남도시개발공사(이하 공사) 개발사",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "028",
# "officeName" : "한겨레",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/028/2017/01/05/logo_028_1_20170105110505.gif' width='206' height='30' alt='한겨레' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/028/2021/10/06/2562872.jpg?type=nf80_54",
# "title" : "“고발장 써 줄테니 대검에 접수하라”…공수처, 김웅-조성은 통화 복구",
# "summary" : "검찰의 고발 사주 의혹을 수사 중인 고위공직자범죄수사처(공수처)가 지난해 4월3일 미래통합당(현 국민의힘) 총선 후보였던 김웅 의원과 이 사건 제보자 조성은씨가 나눈 통화 녹음파일을 복구했다. 당시 김 의원은 조씨에",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "029",
# "officeName" : "디지털타임스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_1_20180718140618.jpg' width='206' height='30' alt='디지털타임스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/029/2021/10/06/2699793.jpg?type=nf80_54",
# "title" : "[기획] 엎친 에너지 대란, 덮친 스태그 공포",
# "summary" : "탄소중립 영향 에너지 수요 급증 공급 부족에 中·인도 등 전력난 에너지가격 폭등 물가 상승 요인 경기회복 이전 \'S의 공포\' 직면 세계 에너지 대란이 현실화하고 있다. 코로나19 이후 세계 경기가 점차 회복세로 접어",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "469",
# "officeName" : "한국일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/469/2018/01/26/logo_469_1_20180126174326.gif' width='206' height='30' alt='한국일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/469/2021/10/06/633582.jpg?type=nf80_54",
# "title" : "\"대장동 50억 리스트는 \'너희 게이트\'\"... 여야 폭탄 돌리기",
# "summary" : "6일 이른바 ‘대장동 50억 리스트’를 둘러싸고 여야의 공방이 불을 뿜었다. 이 리스트는 대장동 개발로 막대한 이익을 챙긴 화천대유자산관리(화천대유)ㆍ천화동인에서 50억 원을 받기로 했다는 정치ㆍ법조계 인사 6명의 ",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "008",
# "officeName" : "머니투데이",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/008/2017/01/05/logo_008_1_20170105110505.gif' width='206' height='30' alt='머니투데이' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/008/2021/10/06/4653282.jpg?type=nf80_54",
# "title" : "대한민국 청정에너지 기술 다 모였다…2021 그린뉴딜 엑스포 개막",
# "summary" : "[[2021 그린뉴딜엑스포]] 국내 유일 그린뉴딜 전시회이자 국내 최대 종합 수소산업 전시회 \'2021 그린뉴딜엑스포\'가 6일 오전 고양 킨텍스 1관에서 사흘간의 열전에 돌입했다. 2021 그린뉴딜엑스포는 국회수소경",
# "publishDate" : "20211007"
# },
# {
# "officeId" : "009",
# "officeName" : "매일경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/009/2017/01/05/logo_009_1_20170105110505.gif' width='206' height='30' alt='매일경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/009/2021/10/06/4861267.jpg?type=nf80_54",
# "title" : "한전 신재생 부담, 5년뒤 8조로 급증",
# "summary" : "전력 공급 신재생 의무비율, 올해 9%서 2026년 25%로 석탄·LNG 가격도 크게 올라…국민에 비용 전가될듯 ◆ 불어나는 신재생 청구서 ◆ 정부가 국내 대규모 발전소에 부과하는 \'신재생에너지 공급 의무화(RPS)",
# "publishDate" : "20211007"
# }
# ]
# ,
# "liveTvList" : [
# {
# "officeId" : "422",
# "articleId" : "0000507879",
# "sectionId" : "74f",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/422/2018/01/10/logo_422_1_20180110175610.png' width='206' height='30' alt='연합뉴스TV 뉴스리뷰' title='' class='' >",
# "officeName" : "연합뉴스TV",
# "title" : "\'대장동 50억 클럽\' 명단 공개…與 \"대장동 국민의힘 5적\"",
# "newsKey" : "74f",
# "naverTvChannelId" : "yonhapnewstv",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/422/2021/10/06/507879.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스리뷰] [앵커] 국정감사 사흘째인 오늘(6일)도 여야는 \'대장동 의혹\'을 놓고 곳곳에서 격론을 벌였습니다. 야당은 화천대유로부터 50억 원을 약속받았다고 알려진 이른바 \'50억 클럽\' 명단을 공개했는데요. 여당",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "449",
# "articleId" : "0000215866",
# "sectionId" : "74b",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/449/2018/01/10/logo_449_1_20180110175910.png' width='206' height='30' alt='채널A 뉴스A' title='' class='' >",
# "officeName" : "채널A",
# "title" : "공수처, 국민의힘 정점식 압수수색…박지원 국정원장 입건",
# "newsKey" : "74b",
# "naverTvChannelId" : "channelanews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/449/2021/10/06/215866.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "뉴스에이 동정민입니다. 검찰이 대장동 개발 특혜 의혹 수사로 속도를 내는 사이, 고위공직자범죄수사처도 고발 사주 의혹 수사의 칼을 뽑았습니다. 고발장의 경로를 확인하기 위해 국민의힘 정점식 의원 사무실을 압수수색했고",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "437",
# "articleId" : "0000277687",
# "sectionId" : "742",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/437/2018/01/10/logo_437_1_20180110175610.png' width='206' height='30' alt='JTBC 뉴스룸' title='' class='' >",
# "officeName" : "JTBC",
# "title" : "[단독] 성남 간부 수첩에 \'대장동 민영 검토\'…\"이재명 지시 적은 것\"",
# "newsKey" : "742",
# "naverTvChannelId" : "jtbcnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/437/2021/10/06/277687.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 오늘(6일) 뉴스룸은 JTBC가 입수한 수첩 내용으로 시작합니다. 2010년 성남시 업무 수첩입니다. 도시 계획을 담당했던 당시 성남시 고위 간부가 사용하던 수첩입니다. 이 수첩엔 업무 내용이 기록돼 있는데",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "056",
# "articleId" : "0011132713",
# "sectionId" : "355",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/056/2018/01/10/logo_056_1_20180110175610.png' width='206' height='30' alt='KBS 뉴스9' title='' class='' >",
# "officeName" : "KBS",
# "title" : "‘특혜 의혹’ 정조준…이성문 전 대표·성남도개공 임직원 줄소환",
# "newsKey" : "355",
# "naverTvChannelId" : "kbsnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/056/2021/10/06/11132713.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : " [앵커] 여러분 안녕하십니까? 대장동 개발 의혹을 수사하고 있는 검찰이 사업 과정에 특혜가 있었는지를 밝히기 위해 관련자들을 잇따라 소환하고 있습니다. 어제(5일) 화천대유 회계담당 임원에 이어, 오늘(6일)은 이",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "214",
# "articleId" : "0001152294",
# "sectionId" : "370",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/214/2018/01/10/logo_214_1_20180110175710.png' width='206' height='30' alt='MBC 뉴스데스크' title='' class='' >",
# "officeName" : "MBC",
# "title" : "[단독] 김웅 \"고발장, 검찰이 억지로 받는 것처럼 해야\"",
# "newsKey" : "370",
# "naverTvChannelId" : "imnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/214/2021/10/06/1152294.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스데스크] ◀ 앵커 ▶ 윤석열 총장 당시 검찰이 야당에 여권 정치인과 언론인 고발을 사주했다는 의혹 관련, MBC의 단독 보도로 시작합니다. 당시, 검찰과 야당이 대리 고발을 치밀하게 모의했다고 봐야 할, 검찰 ",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "057",
# "articleId" : "0001612456",
# "sectionId" : "74e",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/057/2020/06/12/logo_057_1_20200612153812.jpg' width='206' height='30' alt='MBN 종합뉴스' title='' class='' >",
# "officeName" : "MBN",
# "title" : "김주하 앵커가 전하는 10월 6일 종합뉴스 주요뉴스",
# "newsKey" : "74e",
# "naverTvChannelId" : "mbnnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/057/2021/10/06/1612456.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "▶ 화천대유 \'50억 클럽\' 6명 공개…\"사실 무근\" 국민의힘 박수영 의원이 대장동 사업 투자사인 화천대유의 로비 대상이었던 이른바 \'50억 클럽\' 명단에 권순일 전 대법관과 박영수 전 특검, 곽상도 의원 등 6명이",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "055",
# "articleId" : "0000925514",
# "sectionId" : "371",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/055/2018/01/10/logo_055_1_20180110175610.png' width='206' height='30' alt='SBS 8뉴스' title='' class='' >",
# "officeName" : "SBS",
# "title" : "박수영, \'화천대유 50억 클럽\' 6명 공개…\"터무니없다\"",
# "newsKey" : "371",
# "naverTvChannelId" : "sbsnews8",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/055/2021/10/06/925514.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "<앵커> 오늘(6일) 국회 국정감사에서 한 야당 의원이 대장동 개발사업을 주도한 화천대유 측이 50억 원을 주기로 했다는 사람들의 이름이라며 그 명단을 공개했습니다. 이른바 \'50억 클럽\'의 명단이라면서 6명의 실명",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "448",
# "articleId" : "0000340786",
# "sectionId" : "750",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/448/2018/08/30/logo_448_1_20180830162730.png' width='206' height='30' alt='TV조선 뉴스9' title='' class='' >",
# "officeName" : "TV조선",
# "title" : "野, 화천대유 \'50억 클럽\' 6명 공개…與 \"국민의힘 게이트\"",
# "newsKey" : "750",
# "naverTvChannelId" : "tvchosunnews",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/448/2021/10/06/340786.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 대장동 개발 의혹의 파장이 걷잡을 없이 번지고 있습니다. 오늘 국회 국정감사장에선 화천대유로부터 거액을 받았거나 받기로 약속했다는 이른바 \'50억 클럽\' 명단이 실명으로 등장했습니다. 퇴직금 명목으로 아들이",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "052",
# "articleId" : "0001649183",
# "sectionId" : "751",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/052/2018/01/10/logo_052_1_20180110175810.png' width='206' height='30' alt='YTN 뉴스나이트' title='' class='' >",
# "officeName" : "YTN",
# "title" : "[날씨] 내일 중부 비...남부 늦더위",
# "newsKey" : "751",
# "naverTvChannelId" : "ytnnews24",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/052/2021/10/06/1649183.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "요즘 중부 지방에서는 높고 파란 가을 하늘을 보기 어렵습니다. 구름이 잔뜩 끼고 곳곳에 비가 내리기도 했는데 내일도 중부 지방을 중심으로 비가 오겠고, 비가 내리면서 서울 낮 기온이 22도에 머무는 등 선선함이 감돌",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# }
# ]
# };
# </script>
# </div>
# <script type="text/javascript">
# 	// page onload 시에 home timelate에서 사용하는 스크립트를 초기화 시켜준다.
# 	jindo.$Fn(function(){
# 		try {
# 			news.home.TopTimelate.Controller.init(_oTopComponentData);
# 		} catch (e) { }
# 	}).attach(window, "load");
# </script>
# <div class="main_space"></div>
# <div class="main" id="container">
# <hr/>
# <div class="main_content main_content_new" id="main_content">
# <div class="main_content_inner _content_inner">
# <div class="main_component droppable" id="today_main_news">
# <div class="com_header">
# <h4 class="tit_h4 tit_main1"><strong>헤드라인 뉴스</strong></h4>
# <p class="news_info_txt">헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>
# </div>
# <!-- [D] 구형: .com_list.com_list_headline, 이시각주요뉴스:.newsnow, 헤드라인뉴스:.hdline_news -->
# <div class="hdline_news">
# <div class="hdline_flick">
# <div class="hdline_flick_item" style="display:block">
# <a class="lnk_hdline_main_article nclicks('mai.image', '88000149_000000000000000000988848', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=215&amp;aid=0000988848">
# <img 2030년까지="" alt="GM " height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/215/2021/10/07/A202110070090_1_20211007102017245.jpg?type=nf300_190" width="300" 것""="" 늘릴="" 두="" 매출="" 배로=""/>
# <div class="hdline_flick_mask">
# <p class="hdline_flick_tit">GM "2030년까지 매출 두 배로 늘릴 것"</p>
# </div>
# </a>
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000149_000000000000000000988848', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110040930_00000001&amp;mode=LSD&amp;mid=shm&amp;oid=215&amp;aid=0000988848">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">34</span>
# </a>
# </div>
# <div class="hdline_flick_item" style="display:none">
# <a class="lnk_hdline_main_article nclicks('mai.image', '88000119_000000000000000001152355', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=214&amp;aid=0001152355">
# <img alt="'도이치모터스 주가조작' 관련자 첫 구속‥1명 잠적" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/214/2021/10/07/today_20211007_061315_1_7_Large_20211007074614506.jpg?type=nf300_190" width="300"/>
# <div class="hdline_flick_mask">
# <p class="hdline_flick_tit">'도이치모터스 주가조작' 관련자 첫 구속‥1명 …</p>
# </div>
# </a>
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000119_000000000000000001152355', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110060010_00000353&amp;mode=LSD&amp;mid=shm&amp;oid=214&amp;aid=0001152355">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">60</span>
# </a>
# </div>
# <div class="hdline_flick_navi">
# <button class="flick_btn_prev nclicks(mai.prev)" disabled="disabled" onclick="prevRecommend(); " type="button"><span class="blind">이전기사</span></button><button class="flick_btn_next nclicks(mai.next)" onclick="nextRecommend(); " type="button"><span class="blind">다음기사</span></button>
# </div> <!--[D] 버튼 비활성: disabled 속성 추가 -->
# </div>
# <ul class="hdline_article_list">
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '880000FF_000000000000000004719497', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=014&amp;aid=0004719497">
#                                         중국 "오징어 게임 체육복 한국이 베꼈다" 황당 주장
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '880000FF_000000000000000004719497', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110061000_00000211&amp;mode=LSD&amp;mid=shm&amp;oid=014&amp;aid=0004719497">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">49</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '8800006F_000000000000000001475294', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001475294">
#                                         “개인에게 불리한 공매도 폐지” 외친 홍준표
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '8800006F_000000000000000001475294', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110051140_00001703&amp;mode=LSD&amp;mid=shm&amp;oid=005&amp;aid=0001475294">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">39</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '8800006B_000000000000000003102220', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=032&amp;aid=0003102220">
#                                         고 변희수 하사 전역 처분 정당했나…오늘 1심 선고
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '8800006B_000000000000000003102220', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110070540_00000128&amp;mode=LSD&amp;mid=shm&amp;oid=032&amp;aid=0003102220">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">36</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '88000114_000000000000000011133101', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=056&amp;aid=0011133101">
#                                         미·중, 제3국서 고위급 회담…“올해 화상 정상회담 개최 합의”
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000114_000000000000000011133101', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110051510_00000122&amp;mode=LSD&amp;mid=shm&amp;oid=056&amp;aid=0011133101">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">58</span>
# </a>
# </div>
# </li>
# <li>
# <div class="hdline_article_tit">
# <a class="lnk_hdline_article nclicks('mai.text1', '88000107_000000000000000004613360', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004613360">
#                                         美수소·그리드기업 CEO 연달아 만난 최태원…'넷제로' 속도
#                                     </a>
# </div>
# <div class="hdline_cluster_more">
# <a class="lnk_hdline_cluster_more nclicks('mai.clu', '88000107_000000000000000004613360', 'airsGParam', '0', 'news_global_v2.0', 'O6IHnAsxa5o9GImV')" href="/main/clusterArticles.naver?id=c_202110061530_00000334&amp;mode=LSD&amp;mid=shm&amp;oid=015&amp;aid=0004613360">
# <span class="blind">관련기사 개수</span>
# <span class="cluster_more_icon_num">45</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="btn_move">
# <!-- [D] .down_off 또는 .up_off 추가시 '<span class="blind">불가능</span>' 추가 -->
# <span class="move" title="이동">이동</span> <a class="up nclicks(mai.up)" href="#SLELq" title="위로">위로</a> <a class="down_off nclicks(mai.down)" href="#SLELq" title="아래로">아래로<span class="blind">불가능</span></a>
# </div>
# </div>
# <script type="text/javascript">
#             var recommendIdx = 0;
#             var recommendLength = $("#today_main_news .hdline_flick_item").length;
#
#             function prevRecommend() {
#                 if ( recommendIdx-1 >= 0) {
#                     recommendIdx -= 1;
#                 }
#
#                 recBtnDisabled();
#
#                 $("#today_main_news .hdline_flick_item").css("display", "none");
#                 $("#today_main_news .hdline_flick_item").eq(recommendIdx).css("display", "block");
#             }
#
#             function nextRecommend() {
#                 if ( recommendIdx+1 < recommendLength) {
#                     recommendIdx += 1;
#                 }
#
#                 recBtnDisabled();
#
#                 $("#today_main_news .hdline_flick_item").css("display", "none");
#                 $("#today_main_news .hdline_flick_item").eq(recommendIdx).css("display", "block");
#             }
#
#             function recBtnDisabled() {
#                 $("#today_main_news .flick_btn_prev").removeAttr("disabled");
#                 $("#today_main_news .flick_btn_next").removeAttr("disabled");
#
#                 if ( recommendIdx === 0 ) {
#                     $("#today_main_news .flick_btn_prev").attr("disabled", "disabled");
#                 }
#                 if ( recommendIdx === recommendLength -1 ) {
#                     $("#today_main_news .flick_btn_next").attr("disabled", "disabled");
#                 }
#             }
#         </script>
# <div class="main_component droppable" id="section_politics">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(pol.title)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h4>
# <span class="tit_sub">
# <a class="nclicks(pol.common)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">일반</a><span class="bar"></span>
# <a class="nclicks(pol.party)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당</a><span class="bar"></span>
# <a class="nclicks(pol.chung)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">청와대</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010756422">
# <img alt='홍준표, 윤석열 겨냥 "미신 휩싸인 후보론 본선서 못 이겨"' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/003/2021/10/07/10756422.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0010756422">홍준표, 윤석열 겨냥 "미신 휩싸인 후보론 본선서 못 이겨"</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=119&amp;aid=0002536032">
# <strong>국민의힘 최고위, '이재명 대장동 게이트' 특검 관철에 화력 총공세</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">데일리안</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0001896391">
# <strong>"이재명 성남시, 화천대유 물량 늘리고 임대주택 줄여"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">헤럴드경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003140640">
# <strong>진중권의 예언? "한달 후 최종후보는 尹…洪은 역선택일 뿐"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000765143">
# <strong>김웅·조성은 녹취록 공개에 與 “檢 선거개입 방증…김웅 제명하라”</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선비즈</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000127_000000000000000010756422', 'airsGParam', '0', 'news_sec_v2.0', '9vrEisRFX56JfV6z')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0004979763">
# <strong>결국 용두사미로 끝난 ‘여중사 셀프수사 결과’</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(soc.move)" title="이동">이동</span>
# <a class="up nclicks(soc.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(soc.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_economy">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(eco.title)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h4>
# <span class="tit_sub">
# <a class="nclicks(eco.common)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">일반</a><span class="bar"></span>
# <a class="nclicks(eco.finance)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융</a><span class="bar"></span>
# <a class="nclicks(eco.domestic)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=417&amp;aid=0000741315">
# <img alt='영끌·빚투족 어쩌나… 하나금융연구소 "내년 기준금리 1.25% 전망"' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/417/2021/10/07/741315.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=417&amp;aid=0000741315">영끌·빚투족 어쩌나… 하나금융연구소 "내년 기준금리 1.25% 전망"</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=016&amp;aid=0001896400">
# <strong>‘폐기물 업체 10곳 품은’ SK에코플랜트, 추가인수 추진</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">헤럴드경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=366&amp;aid=0000765146">
# <strong>청년주택으로 청년 울린 서울 동작구… “입주하려면 자기소개서 써라” 논란</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">조선비즈</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=011&amp;aid=0003970484">
# <strong>[주식초고수는 지금] MSCI 지수 편입 기대감에 엘앤에프, 최다 거래 몰려</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">서울경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=011&amp;aid=0003970482">
# <strong>‘LH, 대장동 공공개발 왜 포기했나’ LH국감에도 번진 대장동 이슈</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">서울경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8812805E_000000000000000000741315', 'airsGParam', '0', 'news_sec_v2.0', 'Ccvxr8d9QGaPeuqZ')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004979772">
# <strong>코스피 급락장에도 '총알' 늘린 개미들…투자자예탁금 70兆 돌파</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(pol.move)" title="이동">이동</span>
# <a class="up nclicks(pol.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(pol.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_society">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(soc.title)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h4>
# <span class="tit_sub">
# <a class="nclicks(soc.common)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">일반</a><span class="bar"></span>
# <a class="nclicks(soc.edu)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육</a><span class="bar"></span>
# <a class="nclicks(soc.labor)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000D1_000000000000000003220747', 'airsGParam', '0', 'news_sec_v2.0', 'feF6zE5ZHM1U1Yzx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=081&amp;aid=0003220747">
# <img alt="“상사가 아내 성폭행” 폭로…‘알라븅’ 문자에 ‘무혐의’ 종결" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/081/2021/10/07/3220747.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000D1_000000000000000003220747', 'airsGParam', '0', 'news_sec_v2.0', 'feF6zE5ZHM1U1Yzx')" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=081&amp;aid=0003220747">“상사가 아내 성폭행” 폭로…‘알라븅’ 문자에 ‘무혐의’ 종결</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# ...
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087472");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="da" id="doubleDA"></div>
# <div class="section" style="margin-bottom:20px;">
# <h4 class="eng_tit">TODAY</h4>
# <em class="today_info">10.07<span class="today_info_day">(목)</span></em>
# <div class="today" id="today_content">
# <div class="today_inner">
# <h5>공지</h5>
# <ul>
# <li> <a class="nclicks(rig.today)" href="https://news.naver.com/main/ombudsman/readView.naver?notiId=584"> <strong>언론사 편집판 프리미엄콘텐츠 영역 신설 안내</strong> </a> </li>
# <li> <a class="nclicks(rig.today)" href="https://news.naver.com/main/ombudsman/readView.naver?notiId=579"> <strong>댓글 언론사별 선택제 기사단위로 확대 안내</strong> </a> </li>
# </ul>
# </div>
# <div class="today_inner">
# <h5> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=nws_nex&amp;fbm=1&amp;ie=utf8&amp;query=%EC%98%A4%EB%8A%98+%EB%82%A0%EC%94%A8">날씨</a> </h5>
# <ul>
# <li> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=mns_nex&amp;fbm=1&amp;ie=utf8&amp;query=%EC%98%A4%EB%8A%98+%EB%82%A0%EC%94%A8" target="_blank"> 실시간 기상 정보 확인하기 <i aria-hidden="true" class="ico_link_arrow"></i> </a> </li>
# </ul>
# </div>
# <div class="today_inner">
# <h5> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?sm=tab_hty.top&amp;where=nexearch&amp;query=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;oquery=%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;tqi=UZ%2FB6dpySDVssZJtRR8ssssssE8-265238">운세</a> </h5>
# <ul>
# <li> <a class="nclicks(rig.today)" href="https://search.naver.com/search.naver?sm=tab_hty.top&amp;where=nexearch&amp;query=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;oquery=%EB%9D%A0%EB%B3%84+%EC%9A%B4%EC%84%B8&amp;tqi=UZ%2FB6dpySDVssZJtRR8ssssssE8-265238" target="_blank"> 오늘의 띠별 운세 확인하기 <i aria-hidden="true" class="ico_link_arrow"></i> </a> </li>
# </ul>
# </div>
# <div class="today_finance">
# <h5 class="blind">코스피,코스닥 지수</h5>
# <ul>
# <li> <a class="b nclicks(rig.today)" href="https://finance.naver.com/sise/sise_index.naver?code=KOSPI" target="_blank"> <strong>코스피</strong>
# <div class="num">
#        2,958.31
#       </div>
# <div class="num up">
# <i>상승</i>50.00
#       </div> </a> </li>
# <li> <a class="b nclicks(rig.today)" href="https://finance.naver.com/sise/sise_index.naver?code=KOSDAQ" target="_blank"> <strong>코스닥</strong>
# <div class="num">
#        947.41
#       </div>
# <div class="num up">
# <i>상승</i>25.05
#       </div> </a> </li>
# </ul>
# </div>
# <form action="https://finance.naver.com/search/search.naver" id="stockForm" method="get" name="right.today.stockForm" onsubmit="return stock_search_1078898(); return false;" target="_blank">
# <fieldset>
# <legend>증권 종목검색</legend>
# <label class="blind" for="stockTodaySearchQuery_1078898">검색어 입력</label>
# <input class="finance_search_input" id="stockTodaySearchQuery_1078898" name="query" placeholder="종목검색" type="text">
# <button class="finance_search_btn nclicks(rig.today)">종목검색</button>
# </input></fieldset>
# </form>
# </div>
# </div>
# <script type="text/javascript">
# function stock_search_1078898() {
# var stockObj = jindo.$('stockTodaySearchQuery_1078898');
# var searchQuery = stockObj.value.replace(/[ ]/g, "");
# stockObj.value = searchQuery;
# if (searchQuery == '') {
# alert("검색 조건이 없습니다.");
# return false;
# }
# }
# </script>
# <div class="section">
# <h4>만평</h4>
# <div class="img_rolling v1" id="rightOpinionCartoonPhoto4_1078954">
# <div class="_1" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#032_0003102169"> <img alt="2021년 10월 7일 [김용민의 그림마당]" height="180" src="https://mimgnews.pstatic.net/image/origin/032/2021/10/06/3102169.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">경향신문</span> </span> </span> </img></a>
# </div>
# <div class="_2" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#081_0003220585"> <img alt="[만평] 조기영의 세상터치 2021년 10월 7일" height="180" src="https://mimgnews.pstatic.net/image/origin/081/2021/10/06/3220585.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">서울신문</span> </span> </span> </img></a>
# </div>
# <div class="_3" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#028_0002562861"> <img alt="10월 7일 한겨레 그림판" height="180" src="https://mimgnews.pstatic.net/image/origin/028/2021/10/06/2562861.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">한겨레</span> </span> </span> </img></a>
# </div>
# <div class="_4" style="display: none;">
# <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#025_0003140440"> <img alt="[박용석 만평] 10월 7일" height="180" src="https://mimgnews.pstatic.net/image/origin/025/2021/10/06/3140440.jpg?type=nf300_180_q90" width="300"> <span class="trans_border"></span> <span class="text_inner"> <span class="text_area"></span> <span class="text"> <span class="dsc">중앙일보</span> </span> </span> </img></a>
# </div>
# <ul style="display: none;">
# </ul>
# <ul class="_temp" style="display: none;">
#    shuffle 이전 위치
#    <li class="_1"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#032_0003102169"> <img alt="2021년 10월 7일 [김용민의 그림마당]" height="45" src="https://mimgnews.pstatic.net/image/origin/032/2021/10/06/3102169.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_2"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#081_0003220585"> <img alt="[만평] 조기영의 세상터치 2021년 10월 7일" height="45" src="https://mimgnews.pstatic.net/image/origin/081/2021/10/06/3220585.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_3"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#028_0002562861"> <img alt="10월 7일 한겨레 그림판" height="45" src="https://mimgnews.pstatic.net/image/origin/028/2021/10/06/2562861.jpg?type=nf73_45" width="73"> <span class="trans_border2"></span> </img></a> </li>
# <li class="_4"> <a href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307#025_0003140440"> <img alt="[박용석 만평] 10월 7일" height="45" src="https://mimgnews.pstatic.net/image/origin/025/2021/10/06/3140440.jpg?type=nf74_45" width="74"> <span class="trans_border2"></span> </img></a> </li>
# </ul>
# </div>
# <a class="more_link" href="/main/cartoongallery/index.naver?mid=pho&amp;sid2=307" title="만평 더보기"><span class="blind">만평</span>더보기</a>
# </div>
# <script type="text/javascript">
# (function () {
# rightOpinionCartoonPhoto4 = {
# _weHighLighted: null,
# _nIntervarlId: null,
# init: function (sId) {
# this.elContainer = jindo.$(sId);
# if (!this.elContainer) {
# return;
# }
# this.assign();
# this.shuffle();
# this.attach();
# },
# assign: function () {
# this.waDiv = jindo.$ElementList(jindo.$$('div', this.elContainer));
# this.weUl = jindo.$Element(jindo.$$.getSingle('ul', this.elContainer));
# },
# shuffle: function () {
# var weUl = this.weUl;
# var waLiTemp = jindo.$A(jindo.$$('ul._temp li', this.elContainer));
# var waShuffledLi = waLiTemp.shuffle();
# waShuffledLi.forEach(function (v, i, a) {
# weUl.append(v);
# });
# this.change(waShuffledLi.get(0));
# weUl.show();
# },
# attach: function () {
# var aLi = jindo.$$('li', this.weUl.$value());
# jindo.$Fn(this.choose, this).attach(aLi, 'mouseenter');
# },
# choose: function (event) {
# this.change(event.currentElement);
# },
# change: function (el) {
# this.showDivByClassName(jindo.$S(el.className.replace('on', '')).trim().toString());
# this.toggleHighlight(el);
# },
# showDivByClassName: function (sClassName) {
# var sCssQuery = 'div.' + sClassName;
# var weDiv = jindo.$Element(jindo.$$.getSingle(sCssQuery, this.elContainer));
# this.waDiv.hide();
# weDiv.show();
# },
# toggleHighlight: function (el) {
# if (this._weHighLighted) {
# this._weHighLighted.removeClass('on');
# }
# this._weHighLighted = jindo.$Element(el);
# this._weHighLighted.addClass('on');
# },
# next: function () {
# var weLi = this.weUl.child(function (v) {
# return v.hasClass('on');
# })[0];
# var weNextLi = weLi.next();
# if (!weNextLi) {
# weNextLi = this.weUl.first();
# }
# this.change(weNextLi.$value());
# }
# }
# rightOpinionCartoonPhoto4.init('rightOpinionCartoonPhoto4_1078954');
# })();
# </script>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/182956245_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="da" id="rightDoubleDA" style="display: none"></div>
# <script type="text/javascript">
#             try{
#                 jindo.$("doubleDA").innerHTML = '<div id="daHome_300250" name="daHome_300250" style="width: 300px; height: 250px;"><iframe id="home300250" name="home300250" src="https://veta.naver.com/fxshow?su=SU10306&calp=home" width="300" height="250" marginheight="0" marginwidth="0" border="0" frameborder="0" scrolling="no" align="center" title="우측_뉴스홈_더블플레이광고" data-veta-preview="news_home_02"></iframe></div>';
#             }catch(e){}
#         </script>
# <div class="rightBottomDouble" style="margin-top:36px;"><div data-dom-type="doubleplay_bottom" id="doubleHome300250" name="doubleHome300250" title="더블플레이하단광고"></div></div>
# </div>
# </div>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.naver">마이스크랩</a>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
# new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#
#
#
# news.home.DragController.init();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </div>
# </body>
# </html>
